# %% [markdown]
# # **<span style="color:#250389" > Croisement des données HAL et REVCONF (JSON - fichier : valid_conf) </span>**

# %% [markdown]
# ### **<span style="color:#250389" > Objectifs et definition  </span>**

# %% [markdown]
# L'objectif du  croisement est d'avoir le nombre de  "COMM" par congrès/conférences de 2018 à 2023
# Pour cela nous utilisons 2 fichiers:
#
# 1. 'hal_conf2.csv': concerne les données  extraites de l'API HAL qui ont étés préalablement filtrées puis nettoyées (pour consulter le notebook lié à l'extraction et au nettoyage :  http://localhost:8889/lab/tree/nb_python/Publis_conferences_Inria2rteam.ipynb) : il s'agit de la création du tableau pivot à partir des résultats de l'API avec le remplacement des Team ID par les acronymes pour les équipes Inria (suppression des autres ID).
#
# 3. 'revconf.csv': extraction provenant de la plateforme Revconf, qui répertorie l'ensemble des conférences/congrès qui ont étés saisie par les "auteurs" sur le site de HAL (http://localhost:8889/lab/tree/nb_python/Croisement%20des%20donn%C3%A9es%20HAL%20et%20REVCONF.ipynb)
#
# 5. "df2":  proviennent   du notebook (http://localhost:8888/files/nb_python/ref_publi_merged.ipynb?_xsrf=2%7Cb5ee617c%7Ce4a5f4de3c3b122afac26bddd7fc7fad%7C1718098371), nous permet de filtrer sur les thèmes et les equipes.
#
# Points d'attentions pour "hal_conf":
#
# - La colonne 'Conference' représente  toutes les conférences confondues aussi bien les titres contrôlés ("title" dans le fichier revconf) que les titres affiliés au titre contrôlés (form_title dans le fichier revconf).
# - La colonne 'Publication Date' fait référence à la date de publication (il peut avoir des modifications de faites dans HAL plus tard mais la plateforme revconf ne le prends pas en compte)
# - La colonne 'Publication Count' est le calcul du nombre de com par conférences
# - Les colonnes 'clean_form_title' et  'clean_title' sont des copies de de la colonne "Conférence" sans caractères spéciaux  ==> Certains nom de conférences comportent espaces qui empêchent la reconnaissance des champs.

# %%
import json
import re
# !pip install unidecode
from unidecode import unidecode
import pandas as pd

# Lecture des fichiers

hal_conf=pd.read_csv('hal_conf2.csv', sep=',', index_col=0)
revconf=pd.read_csv('revconf.csv', sep=',', index_col=0)
df2 = pd.read_csv('sigles_et_domaines_pour_Test_nbre_de_revues_.csv')

# On supprime la colonne 'clean_form_title' pour la retraiter par la suite
revconf= revconf.drop(columns=['clean_form_title'])
# Out:
# Requirement already satisfied: unidecode in c:\users\abapst\appdata\local\anaconda3\lib\site-packages (1.2.0)

# %%
# 1er nettoyage : suppression des caractères spéciaux, des espaces
def nettoyer_chaine(chaine):
    # Retirer les espaces
    chaine_sans_espaces = chaine.replace(" ", "")
    # Retirer les caractères spéciaux en gardant uniquement les lettres et chiffres
    chaine_nettoyee = re.sub(r'\W+', '', chaine_sans_espaces)
    return chaine_nettoyee

# 2d nettoyage: suppression des accents
def supprimer_accents(chaine):
    return unidecode(chaine)



# 3ème nettoyage: suppression des accents non reconnus par unicode, texte en minuscule, des doubles espaces, des espaces en début et fin de chaîne
def nettoyer_texte(text):
    # Mettre en minuscules
    text = text.lower()

    # Supprimer les lettres accentuées
    text = unidecode(text)

    # Supprimer les doubles espaces
    text = re.sub(r'\s+', ' ', text)

    # Supprimer les espaces en début et fin de chaîne
    text = text.strip()

    return text

# Création de colonnes "cleannées" pour permettre les croisements 


hal_conf['clean_form_title'] = hal_conf['Conference'].apply(nettoyer_chaine)
hal_conf['clean_title'] = hal_conf['Conference'].apply(nettoyer_chaine)

revconf['clean_title'] = revconf['title'].apply(nettoyer_chaine)
revconf['clean_form_title'] = revconf['form_title'].apply(nettoyer_chaine)

revconf['clean_title'].apply(supprimer_accents)
revconf['clean_form_title'].apply(supprimer_accents)
hal_conf['clean_form_title'].apply(supprimer_accents)
hal_conf['clean_title'].apply(supprimer_accents)

revconf['clean_title'].apply(nettoyer_texte)
revconf['clean_form_title'].apply(nettoyer_texte)
hal_conf['clean_form_title'].apply(nettoyer_texte)
hal_conf['clean_title'].apply(nettoyer_texte)
# Out:
# 0            cdc201958thieeeconferenceondecisionandcontrol
# 1            cdc201958thieeeconferenceondecisionandcontrol
# 2            cdc201958thieeeconferenceondecisionandcontrol
# 3            cdc201958thieeeconferenceondecisionandcontrol
# 4            cdc201958thieeeconferenceondecisionandcontrol
#                                ...
# 12211                        ecoledeprintempsdelachairemmb
# 12212                               ecoledetetempsreel2021
# 12213    itsc201821stieeeinternationalconferenceonintel...
# 12214                           bioimageprocessingworkshop
# 12215         randomwalksandintracellulartransportworkshop
# Name: clean_title, Length: 12216, dtype: object

# %%
revconf
# Out:
#        form_id                                         form_title  form_year  \
# 0            1  I3E 2008 : 8th IFIP Conference on e-Business, ...     2008.0
# 1            2  8th IFIP Conference on e-Business, e-Services ...     2008.0
# 2            3  The 8th IFIP Conference on e-Business, e-Servi...     2008.0
# 3            4  The 8th IFIP Conference on e-Business, e-Servi...     2008.0
# 4            5  I3E 2009 : 9th IFIP Conference on e-Business, ...     2009.0
# ...        ...                                                ...        ...
# 64147    89998  Ibero-Latin-American Congress on Computational...        NaN
# 64148    84862  CLAIB 2022 / CBEB 2022 - IX Latin American Con...     2022.0
# 64149    89999  Latin American Congress on Biomedical Engineer...        NaN
# 64150    82213  CLPsyc 2019 - Sixth Workshop on Computational ...     2019.0
# 64151    90000  Workshop on Computational Linguistics and Clin...        NaN
#
#                                                    title  revconf_siid  \
# 0      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 1      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 2      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 3      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 4      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# ...                                                  ...           ...
# 64147  Ibero-Latin-American Congress on Computational...  RC2450539386
# 64148  Latin American Congress on Biomedical Engineer...  RC5965967315
# 64149  Latin American Congress on Biomedical Engineer...  RC5965967315
# 64150  Workshop on Computational Linguistics and Clin...  RC2020474300
# 64151  Workshop on Computational Linguistics and Clin...  RC2020474300
#
#                                              clean_title  \
# 0          IFIPConferenceoneBusinesseServicesandeSociety
# 1          IFIPConferenceoneBusinesseServicesandeSociety
# 2          IFIPConferenceoneBusinesseServicesandeSociety
# 3          IFIPConferenceoneBusinesseServicesandeSociety
# 4          IFIPConferenceoneBusinesseServicesandeSociety
# ...                                                  ...
# 64147  IberoLatinAmericanCongressonComputationalMetho...
# 64148  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64149  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64150  WorkshoponComputationalLinguisticsandClinicalP...
# 64151  WorkshoponComputationalLinguisticsandClinicalP...
#
#                                         clean_form_title
# 0      I3E20088thIFIPConferenceoneBusinesseServicesan...
# 1      8thIFIPConferenceoneBusinesseServicesandeSocie...
# 2      The8thIFIPConferenceoneBusinesseServicesandeSo...
# 3      The8thIFIPConferenceoneBusinesseServicesandeSo...
# 4      I3E20099thIFIPConferenceoneBusinesseServicesan...
# ...                                                  ...
# 64147  IberoLatinAmericanCongressonComputationalMetho...
# 64148  CLAIB2022CBEB2022IXLatinAmericanCongressonBiom...
# 64149  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64150  CLPsyc2019SixthWorkshoponComputationalLinguist...
# 64151  WorkshoponComputationalLinguisticsandClinicalP...
#
# [64152 rows x 7 columns]

# %%
hal_conf['Team Acronym'] = hal_conf['Team Acronym'].str.upper().str.replace(' ', '')
hal_conf
# Out:
#                                               Conference  Publication Date  \
# 0      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 1      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 2      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 3      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 4      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# ...                                                  ...               ...
# 12211                École de Printemps de la chaire MMB              2023
# 12212                        École d’Été Temps Réel 2021              2021
# 12213  ​ITSC 2018 -  21st IEEE International Conferen...              2018
# 12214                     “Bioimage Processing” workshop              2019
# 12215  “Random Walks and Intracellular Transport” wor...              2019
#
#       Team Acronym  Publication Count  \
# 0        NECS-POST                  6
# 1          BIOCORE                  4
# 2            MCTAO                  3
# 3            VALSE                  3
# 4           ACUMES                  2
# ...            ...                ...
# 12211        MERGE                  1
# 12212       KAIROS                  1
# 12213         RITS                  1
# 12214      SERPICO                  1
# 12215      SERPICO                  1
#
#                                         clean_form_title  \
# 0          CDC201958thIEEEConferenceonDecisionandControl
# 1          CDC201958thIEEEConferenceonDecisionandControl
# 2          CDC201958thIEEEConferenceonDecisionandControl
# 3          CDC201958thIEEEConferenceonDecisionandControl
# 4          CDC201958thIEEEConferenceonDecisionandControl
# ...                                                  ...
# 12211                      ÉcoledePrintempsdelachaireMMB
# 12212                             ÉcoledÉtéTempsRéel2021
# 12213  ITSC201821stIEEEInternationalConferenceonIntel...
# 12214                         BioimageProcessingworkshop
# 12215       RandomWalksandIntracellularTransportworkshop
#
#                                              clean_title
# 0          CDC201958thIEEEConferenceonDecisionandControl
# 1          CDC201958thIEEEConferenceonDecisionandControl
# 2          CDC201958thIEEEConferenceonDecisionandControl
# 3          CDC201958thIEEEConferenceonDecisionandControl
# 4          CDC201958thIEEEConferenceonDecisionandControl
# ...                                                  ...
# 12211                      ÉcoledePrintempsdelachaireMMB
# 12212                             ÉcoledÉtéTempsRéel2021
# 12213  ITSC201821stIEEEInternationalConferenceonIntel...
# 12214                         BioimageProcessingworkshop
# 12215       RandomWalksandIntracellularTransportworkshop
#
# [12216 rows x 6 columns]

# %%
#  data qui nous permettra de filtrer sur les équipes
df2['SigleBastri'] = df2['SigleBastri'].str.upper().str.replace(' ', '')
df2['sigle'] = df2['sigle'].str.upper().str.replace(' ', '')
df2
# Out:
#        siidRNSR                            Thème anglais    SigleBastri  \
# 0    200818987H                    Computational Biology            ABS
# 1    202324373X  Computational Neuroscience and Medicine    AISTROSIGHT
# 2    202324373X  Computational Neuroscience and Medicine    AISTROSIGHT
# 3    201120772K                    Computational Biology           AMIB
# 4    201622254Z                    Computational Biology         AMIBIO
# ..          ...                                      ...            ...
# 96   202224249S  Computational Neuroscience and Medicine           SODA
# 97   201622153P                    Computational Biology       TAPDANCE
# 98   200718385H                    Computational Biology  VIRTUALPLANTS
# 99   200518339S  Computational Neuroscience and Medicine        VISAGES
# 100  201622140A   Modeling and Control for Life Sciences           XPOP
#
#              sigle  NonPertinentDansHal siidEquipeGroupe idStructureHal
# 0              ABS                  NaN          GS0184O          51872
# 1              NaN                  NaN              NaN        1152689
# 2              NaN                  NaN              NaN        1152689
# 3             AMIB                  NaN          GS0318Q         103784
# 4           AMIBIO                  NaN          GS0781D         485707
# ..             ...                  ...              ...            ...
# 96            SODA                  NaN          GS0918E        1093353
# 97        TAPDANCE                  NaN          GS0753A         461293
# 98   VIRTUALPLANTS                  NaN          GS0152C          21925
# 99         VISAGES                  NaN          GS0103J   11869;491318
# 100           XPOP                  NaN          GS0737L         454595
#
# [101 rows x 7 columns]

# %%
df2.describe(include='all')
# Out:
#           siidRNSR                            Thème anglais SigleBastri  \
# count          101                                      101         101
# unique          74                                        3          73
# top     201421109N  Computational Neuroscience and Medicine       MAMBA
# freq             4                                       42           4
# mean           NaN                                      NaN         NaN
# std            NaN                                      NaN         NaN
# min            NaN                                      NaN         NaN
# 25%            NaN                                      NaN         NaN
# 50%            NaN                                      NaN         NaN
# 75%            NaN                                      NaN         NaN
# max            NaN                                      NaN         NaN
#
#         sigle  NonPertinentDansHal siidEquipeGroupe  \
# count      89                  0.0               89
# unique     65                  NaN               65
# top     MAMBA                  NaN          GS0604V
# freq        4                  NaN                4
# mean      NaN                  NaN              NaN
# std       NaN                  NaN              NaN
# min       NaN                  NaN              NaN
# 25%       NaN                  NaN              NaN
# 50%       NaN                  NaN              NaN
# 75%       NaN                  NaN              NaN
# max       NaN                  NaN              NaN
#
#                       idStructureHal
# count                            101
# unique                            74
# top     240018;454654;542023;1005056
# freq                               4
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN

# %% [markdown]
# ### **<span style="color:#250389" >Premier test avec un croisement sur "clean_form_title" </span>**

# %%
tab_merged=pd.merge(hal_conf, revconf, on=['clean_form_title'] , how='left', indicator=True)
tab_merged
# Out:
#                                               Conference  Publication Date  \
# 0      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 1      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 2      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 3      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 4      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# ...                                                  ...               ...
# 13804  ​ITSC 2018 -  21st IEEE International Conferen...              2018
# 13805                     “Bioimage Processing” workshop              2019
# 13806                     “Bioimage Processing” workshop              2019
# 13807  “Random Walks and Intracellular Transport” wor...              2019
# 13808  “Random Walks and Intracellular Transport” wor...              2019
#
#       Team Acronym  Publication Count  \
# 0        NECS-POST                  6
# 1        NECS-POST                  6
# 2          BIOCORE                  4
# 3          BIOCORE                  4
# 4            MCTAO                  3
# ...            ...                ...
# 13804         RITS                  1
# 13805      SERPICO                  1
# 13806      SERPICO                  1
# 13807      SERPICO                  1
# 13808      SERPICO                  1
#
#                                         clean_form_title  \
# 0          CDC201958thIEEEConferenceonDecisionandControl
# 1          CDC201958thIEEEConferenceonDecisionandControl
# 2          CDC201958thIEEEConferenceonDecisionandControl
# 3          CDC201958thIEEEConferenceonDecisionandControl
# 4          CDC201958thIEEEConferenceonDecisionandControl
# ...                                                  ...
# 13804  ITSC201821stIEEEInternationalConferenceonIntel...
# 13805                         BioimageProcessingworkshop
# 13806                         BioimageProcessingworkshop
# 13807       RandomWalksandIntracellularTransportworkshop
# 13808       RandomWalksandIntracellularTransportworkshop
#
#                                            clean_title_x  form_id  \
# 0          CDC201958thIEEEConferenceonDecisionandControl  40718.0
# 1          CDC201958thIEEEConferenceonDecisionandControl  40724.0
# 2          CDC201958thIEEEConferenceonDecisionandControl  40718.0
# 3          CDC201958thIEEEConferenceonDecisionandControl  40724.0
# 4          CDC201958thIEEEConferenceonDecisionandControl  40718.0
# ...                                                  ...      ...
# 13804  ITSC201821stIEEEInternationalConferenceonIntel...  13546.0
# 13805                         BioimageProcessingworkshop  54206.0
# 13806                         BioimageProcessingworkshop  54207.0
# 13807       RandomWalksandIntracellularTransportworkshop  54208.0
# 13808       RandomWalksandIntracellularTransportworkshop  54209.0
#
#                                               form_title  form_year  \
# 0      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# 1      CDC 2019 - 58thIEEE Conference on Decision and...     2019.0
# 2      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# 3      CDC 2019 - 58thIEEE Conference on Decision and...     2019.0
# 4      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# ...                                                  ...        ...
# 13804  ITSC 2018 – 21st IEEE International Conference...     2018.0
# 13805                     "Bioimage Processing" workshop     2019.0
# 13806                     “Bioimage Processing” workshop        NaN
# 13807  "Random Walks and Intracellular Transport" wor...     2019.0
# 13808  “Random Walks and Intracellular Transport” wor...        NaN
#
#                                                    title  revconf_siid  \
# 0                IEEE Conference on Decision and Control  RC8095363186
# 1                IEEE Conference on Decision and Control  RC8095363186
# 2                IEEE Conference on Decision and Control  RC8095363186
# 3                IEEE Conference on Decision and Control  RC8095363186
# 4                IEEE Conference on Decision and Control  RC8095363186
# ...                                                  ...           ...
# 13804  International IEEE Conference on Intelligent T...  RC1769683265
# 13805                      Bio-Image Processing Workshop  RC9065248414
# 13806                      Bio-Image Processing Workshop  RC9065248414
# 13807  Random Walks and Intracellular Transport Workshop  RC5072176599
# 13808  Random Walks and Intracellular Transport Workshop  RC5072176599
#
#                                            clean_title_y _merge
# 0                     IEEEConferenceonDecisionandControl   both
# 1                     IEEEConferenceonDecisionandControl   both
# 2                     IEEEConferenceonDecisionandControl   both
# 3                     IEEEConferenceonDecisionandControl   both
# 4                     IEEEConferenceonDecisionandControl   both
# ...                                                  ...    ...
# 13804  InternationalIEEEConferenceonIntelligentTransp...   both
# 13805                         BioImageProcessingWorkshop   both
# 13806                         BioImageProcessingWorkshop   both
# 13807       RandomWalksandIntracellularTransportWorkshop   both
# 13808       RandomWalksandIntracellularTransportWorkshop   both
#
# [13809 rows x 13 columns]

# %%
tab_merged['_merge'].unique()
# Out:
# ['both', 'left_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
tab_merged_bo=tab_merged.loc[tab_merged['_merge']=='both']
tab_merged_bo
# Out:
#                                               Conference  Publication Date  \
# 0      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 1      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 2      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 3      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 4      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# ...                                                  ...               ...
# 13804  ​ITSC 2018 -  21st IEEE International Conferen...              2018
# 13805                     “Bioimage Processing” workshop              2019
# 13806                     “Bioimage Processing” workshop              2019
# 13807  “Random Walks and Intracellular Transport” wor...              2019
# 13808  “Random Walks and Intracellular Transport” wor...              2019
#
#       Team Acronym  Publication Count  \
# 0        NECS-POST                  6
# 1        NECS-POST                  6
# 2          BIOCORE                  4
# 3          BIOCORE                  4
# 4            MCTAO                  3
# ...            ...                ...
# 13804         RITS                  1
# 13805      SERPICO                  1
# 13806      SERPICO                  1
# 13807      SERPICO                  1
# 13808      SERPICO                  1
#
#                                         clean_form_title  \
# 0          CDC201958thIEEEConferenceonDecisionandControl
# 1          CDC201958thIEEEConferenceonDecisionandControl
# 2          CDC201958thIEEEConferenceonDecisionandControl
# 3          CDC201958thIEEEConferenceonDecisionandControl
# 4          CDC201958thIEEEConferenceonDecisionandControl
# ...                                                  ...
# 13804  ITSC201821stIEEEInternationalConferenceonIntel...
# 13805                         BioimageProcessingworkshop
# 13806                         BioimageProcessingworkshop
# 13807       RandomWalksandIntracellularTransportworkshop
# 13808       RandomWalksandIntracellularTransportworkshop
#
#                                            clean_title_x  form_id  \
# 0          CDC201958thIEEEConferenceonDecisionandControl  40718.0
# 1          CDC201958thIEEEConferenceonDecisionandControl  40724.0
# 2          CDC201958thIEEEConferenceonDecisionandControl  40718.0
# 3          CDC201958thIEEEConferenceonDecisionandControl  40724.0
# 4          CDC201958thIEEEConferenceonDecisionandControl  40718.0
# ...                                                  ...      ...
# 13804  ITSC201821stIEEEInternationalConferenceonIntel...  13546.0
# 13805                         BioimageProcessingworkshop  54206.0
# 13806                         BioimageProcessingworkshop  54207.0
# 13807       RandomWalksandIntracellularTransportworkshop  54208.0
# 13808       RandomWalksandIntracellularTransportworkshop  54209.0
#
#                                               form_title  form_year  \
# 0      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# 1      CDC 2019 - 58thIEEE Conference on Decision and...     2019.0
# 2      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# 3      CDC 2019 - 58thIEEE Conference on Decision and...     2019.0
# 4      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# ...                                                  ...        ...
# 13804  ITSC 2018 – 21st IEEE International Conference...     2018.0
# 13805                     "Bioimage Processing" workshop     2019.0
# 13806                     “Bioimage Processing” workshop        NaN
# 13807  "Random Walks and Intracellular Transport" wor...     2019.0
# 13808  “Random Walks and Intracellular Transport” wor...        NaN
#
#                                                    title  revconf_siid  \
# 0                IEEE Conference on Decision and Control  RC8095363186
# 1                IEEE Conference on Decision and Control  RC8095363186
# 2                IEEE Conference on Decision and Control  RC8095363186
# 3                IEEE Conference on Decision and Control  RC8095363186
# 4                IEEE Conference on Decision and Control  RC8095363186
# ...                                                  ...           ...
# 13804  International IEEE Conference on Intelligent T...  RC1769683265
# 13805                      Bio-Image Processing Workshop  RC9065248414
# 13806                      Bio-Image Processing Workshop  RC9065248414
# 13807  Random Walks and Intracellular Transport Workshop  RC5072176599
# 13808  Random Walks and Intracellular Transport Workshop  RC5072176599
#
#                                            clean_title_y _merge
# 0                     IEEEConferenceonDecisionandControl   both
# 1                     IEEEConferenceonDecisionandControl   both
# 2                     IEEEConferenceonDecisionandControl   both
# 3                     IEEEConferenceonDecisionandControl   both
# 4                     IEEEConferenceonDecisionandControl   both
# ...                                                  ...    ...
# 13804  InternationalIEEEConferenceonIntelligentTransp...   both
# 13805                         BioImageProcessingWorkshop   both
# 13806                         BioImageProcessingWorkshop   both
# 13807       RandomWalksandIntracellularTransportWorkshop   both
# 13808       RandomWalksandIntracellularTransportWorkshop   both
#
# [12917 rows x 13 columns]

# %%
tab_merged_lo=tab_merged.loc[tab_merged['_merge']=='left_only']
tab_merged_lo
# Out:
#                                               Conference  Publication Date  \
# 1138                                 Séminaire du LIRIMA              2019
# 1139                                 Séminaire du LIRIMA              2019
# 1140                                 Séminaire du LIRIMA              2019
# 1141                                 Séminaire du LIRIMA              2020
# 1142                                 Séminaire du LIRIMA              2020
# ...                                                  ...               ...
# 13777  iMIMIC 2022 - Workshop on Interpretability of ...              2022
# 13783  international Conference on 'Future is Urban' ...              2021
# 13785  jspyrene2020 : Journée Scientifique autour du ...              2020
# 13799  École Doctorale Sociétés, Communication, Arts,...              2021
# 13800                École de Printemps de la chaire MMB              2023
#
#       Team Acronym  Publication Count  \
# 1138        ZENITH                  1
# 1139         CIDRE                  1
# 1140     DEDUCTEAM                  1
# 1141       MIMESIS                  1
# 1142       KERDATA                  1
# ...            ...                ...
# 13777      STATIFY                  1
# 13783        STEEP                  1
# 13785       CAGIRE                  1
# 13799  MULTISPEECH                  1
# 13800        MERGE                  1
#
#                                         clean_form_title  \
# 1138                                   SéminaireduLIRIMA
# 1139                                   SéminaireduLIRIMA
# 1140                                   SéminaireduLIRIMA
# 1141                                   SéminaireduLIRIMA
# 1142                                   SéminaireduLIRIMA
# ...                                                  ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...
# 13783         internationalConferenceonFutureisUrban2021
# 13785  jspyrene2020JournéeScientifiqueautourducluster...
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...
# 13800                      ÉcoledePrintempsdelachaireMMB
#
#                                            clean_title_x  form_id form_title  \
# 1138                                   SéminaireduLIRIMA      NaN        NaN
# 1139                                   SéminaireduLIRIMA      NaN        NaN
# 1140                                   SéminaireduLIRIMA      NaN        NaN
# 1141                                   SéminaireduLIRIMA      NaN        NaN
# 1142                                   SéminaireduLIRIMA      NaN        NaN
# ...                                                  ...      ...        ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...      NaN        NaN
# 13783         internationalConferenceonFutureisUrban2021      NaN        NaN
# 13785  jspyrene2020JournéeScientifiqueautourducluster...      NaN        NaN
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...      NaN        NaN
# 13800                      ÉcoledePrintempsdelachaireMMB      NaN        NaN
#
#        form_year title revconf_siid clean_title_y     _merge
# 1138         NaN   NaN          NaN           NaN  left_only
# 1139         NaN   NaN          NaN           NaN  left_only
# 1140         NaN   NaN          NaN           NaN  left_only
# 1141         NaN   NaN          NaN           NaN  left_only
# 1142         NaN   NaN          NaN           NaN  left_only
# ...          ...   ...          ...           ...        ...
# 13777        NaN   NaN          NaN           NaN  left_only
# 13783        NaN   NaN          NaN           NaN  left_only
# 13785        NaN   NaN          NaN           NaN  left_only
# 13799        NaN   NaN          NaN           NaN  left_only
# 13800        NaN   NaN          NaN           NaN  left_only
#
# [892 rows x 13 columns]

# %%
tab_merged_lo.describe(include='all')
# Out:
#                  Conference  Publication Date Team Acronym  Publication Count  \
# count                   892        892.000000          892         892.000000
# unique                  790               NaN          215                NaN
# top     Séminaire du LIRIMA               NaN     ALMANACH                NaN
# freq                      6               NaN           36                NaN
# mean                    NaN       2020.908072          NaN           1.070628
# std                     NaN          1.533927          NaN           0.332576
# min                     NaN       2018.000000          NaN           1.000000
# 25%                     NaN       2020.000000          NaN           1.000000
# 50%                     NaN       2021.000000          NaN           1.000000
# 75%                     NaN       2022.000000          NaN           1.000000
# max                     NaN       2023.000000          NaN           4.000000
#
#          clean_form_title      clean_title_x  form_id form_title  form_year  \
# count                 892                892      0.0          0        0.0
# unique                785                785      NaN          0        NaN
# top     SéminaireduLIRIMA  SéminaireduLIRIMA      NaN        NaN        NaN
# freq                    6                  6      NaN        NaN        NaN
# mean                  NaN                NaN      NaN        NaN        NaN
# std                   NaN                NaN      NaN        NaN        NaN
# min                   NaN                NaN      NaN        NaN        NaN
# 25%                   NaN                NaN      NaN        NaN        NaN
# 50%                   NaN                NaN      NaN        NaN        NaN
# 75%                   NaN                NaN      NaN        NaN        NaN
# max                   NaN                NaN      NaN        NaN        NaN
#
#        title revconf_siid clean_title_y     _merge
# count      0            0             0        892
# unique     0            0             0          1
# top      NaN          NaN           NaN  left_only
# freq     NaN          NaN           NaN        892
# mean     NaN          NaN           NaN        NaN
# std      NaN          NaN           NaN        NaN
# min      NaN          NaN           NaN        NaN
# 25%      NaN          NaN           NaN        NaN
# 50%      NaN          NaN           NaN        NaN
# 75%      NaN          NaN           NaN        NaN
# max      NaN          NaN           NaN        NaN

# %% [markdown]
# ### **<span style="color:#250389" >Deuxième croisement sur  "clean_title and clean_form_title" </span>**

# %%
merged_df = pd.merge(hal_conf, revconf, left_on='clean_title', right_on='clean_form_title', how='inner')
merged_df
# Out:
#                                               Conference  Publication Date  \
# 0      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 1      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 2      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 3      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# 4      CDC 2019 - 58th IEEE Conference on Decision an...              2019
# ...                                                  ...               ...
# 12912                        École d’Été Temps Réel 2021              2021
# 12913                     “Bioimage Processing” workshop              2019
# 12914                     “Bioimage Processing” workshop              2019
# 12915  “Random Walks and Intracellular Transport” wor...              2019
# 12916  “Random Walks and Intracellular Transport” wor...              2019
#
#       Team Acronym  Publication Count  \
# 0        NECS-POST                  6
# 1        NECS-POST                  6
# 2          BIOCORE                  4
# 3          BIOCORE                  4
# 4            MCTAO                  3
# ...            ...                ...
# 12912       KAIROS                  1
# 12913      SERPICO                  1
# 12914      SERPICO                  1
# 12915      SERPICO                  1
# 12916      SERPICO                  1
#
#                                   clean_form_title_x  \
# 0      CDC201958thIEEEConferenceonDecisionandControl
# 1      CDC201958thIEEEConferenceonDecisionandControl
# 2      CDC201958thIEEEConferenceonDecisionandControl
# 3      CDC201958thIEEEConferenceonDecisionandControl
# 4      CDC201958thIEEEConferenceonDecisionandControl
# ...                                              ...
# 12912                         ÉcoledÉtéTempsRéel2021
# 12913                     BioimageProcessingworkshop
# 12914                     BioimageProcessingworkshop
# 12915   RandomWalksandIntracellularTransportworkshop
# 12916   RandomWalksandIntracellularTransportworkshop
#
#                                        clean_title_x  form_id  \
# 0      CDC201958thIEEEConferenceonDecisionandControl    40718
# 1      CDC201958thIEEEConferenceonDecisionandControl    40724
# 2      CDC201958thIEEEConferenceonDecisionandControl    40718
# 3      CDC201958thIEEEConferenceonDecisionandControl    40724
# 4      CDC201958thIEEEConferenceonDecisionandControl    40718
# ...                                              ...      ...
# 12912                         ÉcoledÉtéTempsRéel2021    83727
# 12913                     BioimageProcessingworkshop    54206
# 12914                     BioimageProcessingworkshop    54207
# 12915   RandomWalksandIntracellularTransportworkshop    54208
# 12916   RandomWalksandIntracellularTransportworkshop    54209
#
#                                               form_title  form_year  \
# 0      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# 1      CDC 2019 - 58thIEEE Conference on Decision and...     2019.0
# 2      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# 3      CDC 2019 - 58thIEEE Conference on Decision and...     2019.0
# 4      CDC 2019 - 58th IEEE Conference on Decision an...     2019.0
# ...                                                  ...        ...
# 12912                        École d’Été Temps Réel 2021     2021.0
# 12913                     "Bioimage Processing" workshop     2019.0
# 12914                     “Bioimage Processing” workshop        NaN
# 12915  "Random Walks and Intracellular Transport" wor...     2019.0
# 12916  “Random Walks and Intracellular Transport” wor...        NaN
#
#                                                    title  revconf_siid  \
# 0                IEEE Conference on Decision and Control  RC8095363186
# 1                IEEE Conference on Decision and Control  RC8095363186
# 2                IEEE Conference on Decision and Control  RC8095363186
# 3                IEEE Conference on Decision and Control  RC8095363186
# 4                IEEE Conference on Decision and Control  RC8095363186
# ...                                                  ...           ...
# 12912                             École d'Été Temps Réel  RC5242169440
# 12913                      Bio-Image Processing Workshop  RC9065248414
# 12914                      Bio-Image Processing Workshop  RC9065248414
# 12915  Random Walks and Intracellular Transport Workshop  RC5072176599
# 12916  Random Walks and Intracellular Transport Workshop  RC5072176599
#
#                                       clean_title_y  \
# 0                IEEEConferenceonDecisionandControl
# 1                IEEEConferenceonDecisionandControl
# 2                IEEEConferenceonDecisionandControl
# 3                IEEEConferenceonDecisionandControl
# 4                IEEEConferenceonDecisionandControl
# ...                                             ...
# 12912                            ÉcoledÉtéTempsRéel
# 12913                    BioImageProcessingWorkshop
# 12914                    BioImageProcessingWorkshop
# 12915  RandomWalksandIntracellularTransportWorkshop
# 12916  RandomWalksandIntracellularTransportWorkshop
#
#                                   clean_form_title_y
# 0      CDC201958thIEEEConferenceonDecisionandControl
# 1      CDC201958thIEEEConferenceonDecisionandControl
# 2      CDC201958thIEEEConferenceonDecisionandControl
# 3      CDC201958thIEEEConferenceonDecisionandControl
# 4      CDC201958thIEEEConferenceonDecisionandControl
# ...                                              ...
# 12912                         ÉcoledÉtéTempsRéel2021
# 12913                     BioimageProcessingworkshop
# 12914                     BioimageProcessingworkshop
# 12915   RandomWalksandIntracellularTransportworkshop
# 12916   RandomWalksandIntracellularTransportworkshop
#
# [12917 rows x 13 columns]

# %%
tab_merged_lo
# Out:
#                                               Conference  Publication Date  \
# 1138                                 Séminaire du LIRIMA              2019
# 1139                                 Séminaire du LIRIMA              2019
# 1140                                 Séminaire du LIRIMA              2019
# 1141                                 Séminaire du LIRIMA              2020
# 1142                                 Séminaire du LIRIMA              2020
# ...                                                  ...               ...
# 13777  iMIMIC 2022 - Workshop on Interpretability of ...              2022
# 13783  international Conference on 'Future is Urban' ...              2021
# 13785  jspyrene2020 : Journée Scientifique autour du ...              2020
# 13799  École Doctorale Sociétés, Communication, Arts,...              2021
# 13800                École de Printemps de la chaire MMB              2023
#
#       Team Acronym  Publication Count  \
# 1138        ZENITH                  1
# 1139         CIDRE                  1
# 1140     DEDUCTEAM                  1
# 1141       MIMESIS                  1
# 1142       KERDATA                  1
# ...            ...                ...
# 13777      STATIFY                  1
# 13783        STEEP                  1
# 13785       CAGIRE                  1
# 13799  MULTISPEECH                  1
# 13800        MERGE                  1
#
#                                         clean_form_title  \
# 1138                                   SéminaireduLIRIMA
# 1139                                   SéminaireduLIRIMA
# 1140                                   SéminaireduLIRIMA
# 1141                                   SéminaireduLIRIMA
# 1142                                   SéminaireduLIRIMA
# ...                                                  ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...
# 13783         internationalConferenceonFutureisUrban2021
# 13785  jspyrene2020JournéeScientifiqueautourducluster...
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...
# 13800                      ÉcoledePrintempsdelachaireMMB
#
#                                            clean_title_x  form_id form_title  \
# 1138                                   SéminaireduLIRIMA      NaN        NaN
# 1139                                   SéminaireduLIRIMA      NaN        NaN
# 1140                                   SéminaireduLIRIMA      NaN        NaN
# 1141                                   SéminaireduLIRIMA      NaN        NaN
# 1142                                   SéminaireduLIRIMA      NaN        NaN
# ...                                                  ...      ...        ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...      NaN        NaN
# 13783         internationalConferenceonFutureisUrban2021      NaN        NaN
# 13785  jspyrene2020JournéeScientifiqueautourducluster...      NaN        NaN
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...      NaN        NaN
# 13800                      ÉcoledePrintempsdelachaireMMB      NaN        NaN
#
#        form_year title revconf_siid clean_title_y     _merge
# 1138         NaN   NaN          NaN           NaN  left_only
# 1139         NaN   NaN          NaN           NaN  left_only
# 1140         NaN   NaN          NaN           NaN  left_only
# 1141         NaN   NaN          NaN           NaN  left_only
# 1142         NaN   NaN          NaN           NaN  left_only
# ...          ...   ...          ...           ...        ...
# 13777        NaN   NaN          NaN           NaN  left_only
# 13783        NaN   NaN          NaN           NaN  left_only
# 13785        NaN   NaN          NaN           NaN  left_only
# 13799        NaN   NaN          NaN           NaN  left_only
# 13800        NaN   NaN          NaN           NaN  left_only
#
# [892 rows x 13 columns]

# %%
revconf
# Out:
#        form_id                                         form_title  form_year  \
# 0            1  I3E 2008 : 8th IFIP Conference on e-Business, ...     2008.0
# 1            2  8th IFIP Conference on e-Business, e-Services ...     2008.0
# 2            3  The 8th IFIP Conference on e-Business, e-Servi...     2008.0
# 3            4  The 8th IFIP Conference on e-Business, e-Servi...     2008.0
# 4            5  I3E 2009 : 9th IFIP Conference on e-Business, ...     2009.0
# ...        ...                                                ...        ...
# 64147    89998  Ibero-Latin-American Congress on Computational...        NaN
# 64148    84862  CLAIB 2022 / CBEB 2022 - IX Latin American Con...     2022.0
# 64149    89999  Latin American Congress on Biomedical Engineer...        NaN
# 64150    82213  CLPsyc 2019 - Sixth Workshop on Computational ...     2019.0
# 64151    90000  Workshop on Computational Linguistics and Clin...        NaN
#
#                                                    title  revconf_siid  \
# 0      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 1      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 2      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 3      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 4      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# ...                                                  ...           ...
# 64147  Ibero-Latin-American Congress on Computational...  RC2450539386
# 64148  Latin American Congress on Biomedical Engineer...  RC5965967315
# 64149  Latin American Congress on Biomedical Engineer...  RC5965967315
# 64150  Workshop on Computational Linguistics and Clin...  RC2020474300
# 64151  Workshop on Computational Linguistics and Clin...  RC2020474300
#
#                                              clean_title  \
# 0          IFIPConferenceoneBusinesseServicesandeSociety
# 1          IFIPConferenceoneBusinesseServicesandeSociety
# 2          IFIPConferenceoneBusinesseServicesandeSociety
# 3          IFIPConferenceoneBusinesseServicesandeSociety
# 4          IFIPConferenceoneBusinesseServicesandeSociety
# ...                                                  ...
# 64147  IberoLatinAmericanCongressonComputationalMetho...
# 64148  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64149  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64150  WorkshoponComputationalLinguisticsandClinicalP...
# 64151  WorkshoponComputationalLinguisticsandClinicalP...
#
#                                         clean_form_title
# 0      I3E20088thIFIPConferenceoneBusinesseServicesan...
# 1      8thIFIPConferenceoneBusinesseServicesandeSocie...
# 2      The8thIFIPConferenceoneBusinesseServicesandeSo...
# 3      The8thIFIPConferenceoneBusinesseServicesandeSo...
# 4      I3E20099thIFIPConferenceoneBusinesseServicesan...
# ...                                                  ...
# 64147  IberoLatinAmericanCongressonComputationalMetho...
# 64148  CLAIB2022CBEB2022IXLatinAmericanCongressonBiom...
# 64149  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64150  CLPsyc2019SixthWorkshoponComputationalLinguist...
# 64151  WorkshoponComputationalLinguisticsandClinicalP...
#
# [64152 rows x 7 columns]

# %% [markdown]
# ### **<span style="color:#250389" > Troisieme croisement avec le "left_only"  (on va merger sur clean_form_title et title) </span>**

# %%
# tab_merged_lo_test = tab_merged_lo.rename(columns={'clean_form_title' : 'clean_title2'})
tab_merged_lo = tab_merged_lo.drop(columns=['_merge'])
# revconf_test = revconf.rename(columns={'clean_title' : 'clean_title2'})

# %%
tab_merged_lo
# Out:
#                                               Conference  Publication Date  \
# 1138                                 Séminaire du LIRIMA              2019
# 1139                                 Séminaire du LIRIMA              2019
# 1140                                 Séminaire du LIRIMA              2019
# 1141                                 Séminaire du LIRIMA              2020
# 1142                                 Séminaire du LIRIMA              2020
# ...                                                  ...               ...
# 13777  iMIMIC 2022 - Workshop on Interpretability of ...              2022
# 13783  international Conference on 'Future is Urban' ...              2021
# 13785  jspyrene2020 : Journée Scientifique autour du ...              2020
# 13799  École Doctorale Sociétés, Communication, Arts,...              2021
# 13800                École de Printemps de la chaire MMB              2023
#
#       Team Acronym  Publication Count  \
# 1138        ZENITH                  1
# 1139         CIDRE                  1
# 1140     DEDUCTEAM                  1
# 1141       MIMESIS                  1
# 1142       KERDATA                  1
# ...            ...                ...
# 13777      STATIFY                  1
# 13783        STEEP                  1
# 13785       CAGIRE                  1
# 13799  MULTISPEECH                  1
# 13800        MERGE                  1
#
#                                         clean_form_title  \
# 1138                                   SéminaireduLIRIMA
# 1139                                   SéminaireduLIRIMA
# 1140                                   SéminaireduLIRIMA
# 1141                                   SéminaireduLIRIMA
# 1142                                   SéminaireduLIRIMA
# ...                                                  ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...
# 13783         internationalConferenceonFutureisUrban2021
# 13785  jspyrene2020JournéeScientifiqueautourducluster...
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...
# 13800                      ÉcoledePrintempsdelachaireMMB
#
#                                            clean_title_x  form_id form_title  \
# 1138                                   SéminaireduLIRIMA      NaN        NaN
# 1139                                   SéminaireduLIRIMA      NaN        NaN
# 1140                                   SéminaireduLIRIMA      NaN        NaN
# 1141                                   SéminaireduLIRIMA      NaN        NaN
# 1142                                   SéminaireduLIRIMA      NaN        NaN
# ...                                                  ...      ...        ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...      NaN        NaN
# 13783         internationalConferenceonFutureisUrban2021      NaN        NaN
# 13785  jspyrene2020JournéeScientifiqueautourducluster...      NaN        NaN
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...      NaN        NaN
# 13800                      ÉcoledePrintempsdelachaireMMB      NaN        NaN
#
#        form_year title revconf_siid clean_title_y
# 1138         NaN   NaN          NaN           NaN
# 1139         NaN   NaN          NaN           NaN
# 1140         NaN   NaN          NaN           NaN
# 1141         NaN   NaN          NaN           NaN
# 1142         NaN   NaN          NaN           NaN
# ...          ...   ...          ...           ...
# 13777        NaN   NaN          NaN           NaN
# 13783        NaN   NaN          NaN           NaN
# 13785        NaN   NaN          NaN           NaN
# 13799        NaN   NaN          NaN           NaN
# 13800        NaN   NaN          NaN           NaN
#
# [892 rows x 12 columns]

# %%
revconf
# Out:
#        form_id                                         form_title  form_year  \
# 0            1  I3E 2008 : 8th IFIP Conference on e-Business, ...     2008.0
# 1            2  8th IFIP Conference on e-Business, e-Services ...     2008.0
# 2            3  The 8th IFIP Conference on e-Business, e-Servi...     2008.0
# 3            4  The 8th IFIP Conference on e-Business, e-Servi...     2008.0
# 4            5  I3E 2009 : 9th IFIP Conference on e-Business, ...     2009.0
# ...        ...                                                ...        ...
# 64147    89998  Ibero-Latin-American Congress on Computational...        NaN
# 64148    84862  CLAIB 2022 / CBEB 2022 - IX Latin American Con...     2022.0
# 64149    89999  Latin American Congress on Biomedical Engineer...        NaN
# 64150    82213  CLPsyc 2019 - Sixth Workshop on Computational ...     2019.0
# 64151    90000  Workshop on Computational Linguistics and Clin...        NaN
#
#                                                    title  revconf_siid  \
# 0      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 1      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 2      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 3      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# 4      IFIP Conference on e-Business, e-Services, and...  RC2040646750
# ...                                                  ...           ...
# 64147  Ibero-Latin-American Congress on Computational...  RC2450539386
# 64148  Latin American Congress on Biomedical Engineer...  RC5965967315
# 64149  Latin American Congress on Biomedical Engineer...  RC5965967315
# 64150  Workshop on Computational Linguistics and Clin...  RC2020474300
# 64151  Workshop on Computational Linguistics and Clin...  RC2020474300
#
#                                              clean_title  \
# 0          IFIPConferenceoneBusinesseServicesandeSociety
# 1          IFIPConferenceoneBusinesseServicesandeSociety
# 2          IFIPConferenceoneBusinesseServicesandeSociety
# 3          IFIPConferenceoneBusinesseServicesandeSociety
# 4          IFIPConferenceoneBusinesseServicesandeSociety
# ...                                                  ...
# 64147  IberoLatinAmericanCongressonComputationalMetho...
# 64148  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64149  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64150  WorkshoponComputationalLinguisticsandClinicalP...
# 64151  WorkshoponComputationalLinguisticsandClinicalP...
#
#                                         clean_form_title
# 0      I3E20088thIFIPConferenceoneBusinesseServicesan...
# 1      8thIFIPConferenceoneBusinesseServicesandeSocie...
# 2      The8thIFIPConferenceoneBusinesseServicesandeSo...
# 3      The8thIFIPConferenceoneBusinesseServicesandeSo...
# 4      I3E20099thIFIPConferenceoneBusinesseServicesan...
# ...                                                  ...
# 64147  IberoLatinAmericanCongressonComputationalMetho...
# 64148  CLAIB2022CBEB2022IXLatinAmericanCongressonBiom...
# 64149  LatinAmericanCongressonBiomedicalEngineeringBr...
# 64150  CLPsyc2019SixthWorkshoponComputationalLinguist...
# 64151  WorkshoponComputationalLinguisticsandClinicalP...
#
# [64152 rows x 7 columns]

# %%
tab_merged3 = pd.merge(tab_merged_lo, revconf, left_on='clean_form_title', right_on='clean_title', how='inner', indicator=True)
tab_merged3
# Out:
# Empty DataFrame
# Columns: [Conference, Publication Date, Team Acronym, Publication Count, clean_form_title_x, clean_title_x, form_id_x, form_title_x, form_year_x, title_x, revconf_siid_x, clean_title_y, form_id_y, form_title_y, form_year_y, title_y, revconf_siid_y, clean_title, clean_form_title_y, _merge]
# Index: []

# %%
# tab_merged3=pd.merge(tab_merged_lo_test, revconf_test, on=['clean_title2'] , how='left', indicator=True)
# tab_merged3

# %%
tab_merged3['_merge'].unique()
# Out:
# [], Categories (3, object): ['left_only', 'right_only', 'both']

# %%
tab_merged_lo=tab_merged.loc[tab_merged['_merge']=='left_only']
tab_merged_lo
# Out:
#                                               Conference  Publication Date  \
# 1138                                 Séminaire du LIRIMA              2019
# 1139                                 Séminaire du LIRIMA              2019
# 1140                                 Séminaire du LIRIMA              2019
# 1141                                 Séminaire du LIRIMA              2020
# 1142                                 Séminaire du LIRIMA              2020
# ...                                                  ...               ...
# 13777  iMIMIC 2022 - Workshop on Interpretability of ...              2022
# 13783  international Conference on 'Future is Urban' ...              2021
# 13785  jspyrene2020 : Journée Scientifique autour du ...              2020
# 13799  École Doctorale Sociétés, Communication, Arts,...              2021
# 13800                École de Printemps de la chaire MMB              2023
#
#       Team Acronym  Publication Count  \
# 1138        ZENITH                  1
# 1139         CIDRE                  1
# 1140     DEDUCTEAM                  1
# 1141       MIMESIS                  1
# 1142       KERDATA                  1
# ...            ...                ...
# 13777      STATIFY                  1
# 13783        STEEP                  1
# 13785       CAGIRE                  1
# 13799  MULTISPEECH                  1
# 13800        MERGE                  1
#
#                                         clean_form_title  \
# 1138                                   SéminaireduLIRIMA
# 1139                                   SéminaireduLIRIMA
# 1140                                   SéminaireduLIRIMA
# 1141                                   SéminaireduLIRIMA
# 1142                                   SéminaireduLIRIMA
# ...                                                  ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...
# 13783         internationalConferenceonFutureisUrban2021
# 13785  jspyrene2020JournéeScientifiqueautourducluster...
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...
# 13800                      ÉcoledePrintempsdelachaireMMB
#
#                                            clean_title_x  form_id form_title  \
# 1138                                   SéminaireduLIRIMA      NaN        NaN
# 1139                                   SéminaireduLIRIMA      NaN        NaN
# 1140                                   SéminaireduLIRIMA      NaN        NaN
# 1141                                   SéminaireduLIRIMA      NaN        NaN
# 1142                                   SéminaireduLIRIMA      NaN        NaN
# ...                                                  ...      ...        ...
# 13777  iMIMIC2022WorkshoponInterpretabilityofMachineI...      NaN        NaN
# 13783         internationalConferenceonFutureisUrban2021      NaN        NaN
# 13785  jspyrene2020JournéeScientifiqueautourducluster...      NaN        NaN
# 13799  ÉcoleDoctoraleSociétésCommunicationArtsLettres...      NaN        NaN
# 13800                      ÉcoledePrintempsdelachaireMMB      NaN        NaN
#
#        form_year title revconf_siid clean_title_y     _merge
# 1138         NaN   NaN          NaN           NaN  left_only
# 1139         NaN   NaN          NaN           NaN  left_only
# 1140         NaN   NaN          NaN           NaN  left_only
# 1141         NaN   NaN          NaN           NaN  left_only
# 1142         NaN   NaN          NaN           NaN  left_only
# ...          ...   ...          ...           ...        ...
# 13777        NaN   NaN          NaN           NaN  left_only
# 13783        NaN   NaN          NaN           NaN  left_only
# 13785        NaN   NaN          NaN           NaN  left_only
# 13799        NaN   NaN          NaN           NaN  left_only
# 13800        NaN   NaN          NaN           NaN  left_only
#
# [892 rows x 13 columns]

# %% [markdown]
# ### **<span style="color:#250389" > FILTRAGE SUR NEURIPS,ICML,AAAI, AISTATS ET LES TEAMS </span>**

# %%
print('Liste des "SigleBastri" à garder pour filtrage:','\n')
print(df2['SigleBastri'].unique())
# Out:
# Liste des "SigleBastri" à garder pour filtrage:
#
# ['ABS' 'AISTROSIGHT' 'AMIB' 'AMIBIO' 'ARAMIS' 'ASCLEPIOS' 'ATHENA'
#  'BAMBOO' 'BEAGLE' 'BIGS' 'BIOCORE' 'BIOVISION' 'BONSAI' 'CAMIN' 'CAPSID'
#  'CARMEN' 'COMMEDIA' 'COMPO' 'CRONOS' 'DEMAR' 'DRACULA' 'DYLISS' 'EMPENN'
#  'EPIMETHEE' 'EPIONE' 'ERABLE' 'GALEN' 'GENSCALE' 'HEKA' 'IBIS' 'INBIO'
#  'LIFEWARE' 'M3DISIM' 'MACBES' 'MAGNOME' 'MAMBA' 'MASAIE' 'MATHNEURO'
#  'MERGE' 'MICROCOSME' 'MIMESIS' 'MIND' 'MNEMOSYNE' 'MODEMIC' 'MONC'
#  'MORPHEME' 'MOSAIC' 'MUSCA' 'MUSCLEES' 'MYCENAE' 'NERV' 'NEUROMATHCOMP'
#  'NEUROSYS' 'NUMED' 'OPIS' 'ORCHESTRON' 'PARIETAL' 'PLEIADE' 'POPIX'
#  'PREMEDICAL' 'REO' 'SAIRPICO' 'SERPICO' 'SHACRA' 'SIMBA' 'SIMBIOTX'
#  'SISTM' 'SISYPHE' 'SODA' 'TAPDANCE' 'VIRTUALPLANTS' 'VISAGES' 'XPOP']

# %%
print('Liste des "sigle" à garder pour filtrage:','\n')
print(df2['sigle'].unique())
# Out:
# Liste des "sigle" à garder pour filtrage:
#
# ['ABS' nan 'AMIB' 'AMIBIO' 'ARAMIS' 'ASCLEPIOS' 'ATHENA' 'BAMBOO' 'BEAGLE'
#  'BIGS' 'BIOCORE' 'BIOVISION' 'BONSAI' 'CAMIN' 'CAPSID' 'CARMEN'
#  'COMMEDIA' 'COMPO' 'DEMAR' 'DRACULA' 'DYLISS' 'VISAGES' 'EPIONE' 'ERABLE'
#  'GALEN' 'GALEN-POST' 'GENSCALE' 'HEKA' 'IBIS' 'INBIO' 'LIFEWARE'
#  'M3DISIM' 'MAGNOME' 'MAMBA' 'MASAIE' 'MATHNEURO' 'MICROCOSME' 'MIMESIS'
#  'MIND' 'MNEMOSYNE' 'MODEMIC' 'MONC' 'MORPHEME' 'MOSAIC' 'MUSCA' 'MYCENAE'
#  'NEUROMATHCOMP' 'NEUROSYS' 'NUMED' 'OPIS' 'ORCHESTRON' 'PARIETAL'
#  'PLEIADE' 'POPIX' 'PREMEDICAL' 'REO' 'REO-POST' 'SERPICO' 'SHACRA'
#  'SIMBIOTX' 'SISTM' 'SISYPHE' 'SODA' 'TAPDANCE' 'VIRTUALPLANTS' 'XPOP']

# %%
df2. describe(include='all')
# Out:
#           siidRNSR                            Thème anglais SigleBastri  \
# count          101                                      101         101
# unique          74                                        3          73
# top     201421109N  Computational Neuroscience and Medicine       MAMBA
# freq             4                                       42           4
# mean           NaN                                      NaN         NaN
# std            NaN                                      NaN         NaN
# min            NaN                                      NaN         NaN
# 25%            NaN                                      NaN         NaN
# 50%            NaN                                      NaN         NaN
# 75%            NaN                                      NaN         NaN
# max            NaN                                      NaN         NaN
#
#         sigle  NonPertinentDansHal siidEquipeGroupe  \
# count      89                  0.0               89
# unique     65                  NaN               65
# top     MAMBA                  NaN          GS0604V
# freq        4                  NaN                4
# mean      NaN                  NaN              NaN
# std       NaN                  NaN              NaN
# min       NaN                  NaN              NaN
# 25%       NaN                  NaN              NaN
# 50%       NaN                  NaN              NaN
# 75%       NaN                  NaN              NaN
# max       NaN                  NaN              NaN
#
#                       idStructureHal
# count                            101
# unique                            74
# top     240018;454654;542023;1005056
# freq                               4
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN

# %%
# title_to_keep = ['Annual Conference on Neural Information Processing Systems','International Conference on Machine Learning', 
                   # 'International Conference on Artificial Intelligence and Statistics', 'National Conference on Artificial Intelligence']

# Filtrage sur les titles contrôlés et les teams
id_to_keep = ['RC9798641609','RC6493598945','RC8357518104','RC7612516265']

# team_acronym_to_keep = ['ABS', 'AISTROSIGHT', 'AMIB', 'AMIBIO', 'ARAMIS', 'ASCLEPIOS',
#        'ATHENA', 'BAMBOO', 'BEAGLE', 'BIGS', 'BIOCORE', 'BIOVISION',
#        'BONSAI', 'CAMIN', 'CAPSID', 'CARMEN', 'COMMEDIA', 'COMPO',
#        'CRONOS', 'DEMAR', 'DRACULA', 'DYLISS', 'EMPENN', 'EPIMETHEE',
#        'EPIONE', 'ERABLE', 'GALEN', 'GENSCALE', 'HEKA', 'IBIS', 'INBIO',
#        'LIFEWARE', 'M3DISIM', 'MACBES', 'MAGNOME', 'MAMBA', 'MASAIE',
#        'MATHNEURO', 'MERGE', 'MICROCOSME', 'MIMESIS', 'MIND', 'MNEMOSYNE',
#        'MODEMIC', 'MONC', 'MORPHEME', 'MOSAIC', 'MUSCA', 'MUSCLEES',
#        'MYCENAE', 'NERV', 'NEUROMATHCOMP', 'NEUROSYS', 'NUMED', 'OPIS',
#        'ORCHESTRON', 'PARIETAL', 'PLEIADE', 'POPIX', 'PREMEDICAL', 'REO',
#        'SAIRPICO', 'SERPICO', 'SHACRA', 'SIMBA', 'SIMBIOTX', 'SISTM',
#        'SISYPHE', 'SODA', 'TAPDANCE', 'VIRTUAL PLANTS', 'VISAGES', 'XPOP']

team_acronym_to_keep =['ABS' , 'AMIB' ,'AMIBIO', 'ARAMIS', 'ASCLEPIOS' ,'ATHENA' ,'BAMBOO', 'BEAGLE',
 'BIGS' ,'BIOCORE' ,'BIOVISION', 'BONSAI', 'CAMIN' ,'CAPSID' ,'CARMEN',
 'COMMEDIA' ,'COMPO', 'DEMAR' ,'DRACULA', 'DYLISS' ,'VISAGES', 'EPIONE', 'ERABLE',
 'GALEN' ,'GALEN-POST' ,'GENSCALE' ,'HEKA' ,'IBIS' ,'INBIO', 'LIFEWARE',
 'M3DISIM' ,'MAGNOME' ,'MAMBA' ,'MASAIE', 'MATHNEURO' ,'MICROCOSME' ,'MIMESIS',
 'MIND' , 'MNEMOSYNE', 'MODEMIC' ,'MONC' ,'MORPHEME', 'MOSAIC' ,'MUSCA', 'MYCENAE',
 'NEUROMATHCOMP', 'NEUROSYS', 'NUMED', 'OPIS' ,'ORCHESTRON', 'PARIETAL',
 'PLEIADE' ,'POPIX' ,'PREMEDICAL', 'REO', 'REO-POST', 'SERPICO', 'SHACRA',
 'SIMBIOTX', 'SISTM' ,'SISYPHE', 'SODA', 'TAPDANCE' ,'VIRTUAL PLANTS' ,'XPOP']


ml_ia_publications  = merged_df[merged_df ['revconf_siid'].isin(id_to_keep)]
ml_ia_publications = ml_ia_publications[ml_ia_publications['Team Acronym'].isin(team_acronym_to_keep)]
# Suppression des colonnes
ml_ia_publications = ml_ia_publications.drop(columns=['clean_title_x', 'form_id' ,'form_year', 'clean_title_y','form_title', 'clean_form_title_y', 'clean_form_title_x'	,'clean_title_x','form_id'])

ml_ia_publications
# Out:
#                                               Conference  Publication Date  \
# 46     NeurIPS 2020 - 34th Conference on Neural Infor...              2020
# 47     NeurIPS 2020 - 34th Conference on Neural Infor...              2020
# 89     NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# 90     NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# 91     NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# ...                                                  ...               ...
# 10815          NeurIPS 2023 Workshop on Diffusion Models              2023
# 10824  Neural Information Processing Systems (NeurIPS...              2023
# 11067  PMLR 2022 - Proceedings of Machine Learning Re...              2022
# 11279  Proceedings of the Neural Information Processi...              2022
# 12845  Workshop on Robustness in Sequence Modeling, 3...              2022
#
#       Team Acronym  Publication Count  \
# 46        PARIETAL                  4
# 47            XPOP                  3
# 89            MIND                  3
# 90            MIND                  3
# 91            MIND                  3
# ...            ...                ...
# 10815       EPIONE                  1
# 10824         MONC                  1
# 11067   PREMEDICAL                  1
# 11279         HEKA                  1
# 12845         OPIS                  1
#
#                                                    title  revconf_siid
# 46     Annual Conference on Neural Information Proces...  RC9798641609
# 47     Annual Conference on Neural Information Proces...  RC9798641609
# 89     Annual Conference on Neural Information Proces...  RC9798641609
# 90     Annual Conference on Neural Information Proces...  RC9798641609
# 91     Annual Conference on Neural Information Proces...  RC9798641609
# ...                                                  ...           ...
# 10815  Annual Conference on Neural Information Proces...  RC9798641609
# 10824  Annual Conference on Neural Information Proces...  RC9798641609
# 11067       International Conference on Machine Learning  RC6493598945
# 11279  Annual Conference on Neural Information Proces...  RC9798641609
# 12845  Annual Conference on Neural Information Proces...  RC9798641609
#
# [126 rows x 6 columns]

# %%
ml_ia_publications.describe(include='all')
# Out:
#                                                Conference  Publication Date  \
# count                                                 126        126.000000
# unique                                                 80               NaN
# top     NeurIPS 2023 – 37th Conference on Neural Infor...               NaN
# freq                                                    9               NaN
# mean                                                  NaN       2021.031746
# std                                                   NaN          1.609653
# min                                                   NaN       2018.000000
# 25%                                                   NaN       2020.000000
# 50%                                                   NaN       2021.000000
# 75%                                                   NaN       2022.000000
# max                                                   NaN       2023.000000
#
#        Team Acronym  Publication Count  \
# count           126         126.000000
# unique           19                NaN
# top        PARIETAL                NaN
# freq             40                NaN
# mean            NaN           1.134921
# std             NaN           0.479219
# min             NaN           1.000000
# 25%             NaN           1.000000
# 50%             NaN           1.000000
# 75%             NaN           1.000000
# max             NaN           4.000000
#
#                                                     title  revconf_siid
# count                                                 126           126
# unique                                                  4             4
# top     Annual Conference on Neural Information Proces...  RC9798641609
# freq                                                   73            73
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN

# %%
ml_ia_publicationsta = ml_ia_publications[ml_ia_publications['Team Acronym'] == 'Mnemosyne']
ml_ia_publicationsta
# Out:
# Empty DataFrame
# Columns: [Conference, Publication Date, Team Acronym, Publication Count, title, revconf_siid]
# Index: []

# %% [markdown]
# On a bien 4 "title"  et 4 "revconf_siid" différents

# %%
ml_ia_publications.columns
# Out:
# Index(['Conference', 'Publication Date', 'Team Acronym', 'Publication Count',
#        'title', 'revconf_siid'],
#       dtype='object')

# %%
# # 1. les doublons d'index
# index_duplicated = ml_ia_publications.index.duplicated()
# if index_duplicated.any():
#     print("Il y a des index dupliqués. Voici les lignes dupliquées :")
#     print(ml_ia_publications[index_duplicated])

# # 2.  les doublons de lignes entières
# rows_duplicated = ml_ia_publications.duplicated()
# if rows_duplicated.any():
#     print("Il y a des lignes dupliquées. Voici les lignes dupliquées :")
#     print( ml_ia_publications[rows_duplicated])

# # 3. les doublons basés sur des colonnes spécifiques
# cols_to_check = ['Conference', 'Publication Date', 'Publication Count', 'title', 'revconf_siid']  # Remplacez par les colonnes pertinentes
# cols_duplicated = ml_ia_publications.duplicated(subset=cols_to_check)
# if cols_duplicated.any():
#     print(f"Il y a des doublons basés sur les colonnes {cols_to_check}. Voici les lignes dupliquées :")
#     print(ml_ia_publications[cols_duplicated])

# # Optionnel : Supprimer les doublons (conserver la première occurrence)
# ml_ia_publications = ml_ia_publications.drop_duplicates()
# print("DataFrame sans doublons :")
# print(ml_ia_publications)

# # Optionnel : Réinitialiser l'index si nécessaire
# ml_ia_publications= ml_ia_publications.reset_index(drop=True)
# print("DataFrame sans doublons avec index réinitialisé :")
# ml_ia_publications

# %%
# Sup des doublons
ml_ia_publications = ml_ia_publications.drop_duplicates(subset=['Conference', 'Publication Count','title', 'Team Acronym'])

# Réorganisation des colonnes
new_order = ['title','revconf_siid','Conference', 'Publication Date', 'Publication Count']
ml_ia_publications = ml_ia_publications[new_order]

ml_ia_publications
# Out:
#                                                    title  revconf_siid  \
# 46     Annual Conference on Neural Information Proces...  RC9798641609
# 47     Annual Conference on Neural Information Proces...  RC9798641609
# 89     Annual Conference on Neural Information Proces...  RC9798641609
# 98     Annual Conference on Neural Information Proces...  RC9798641609
# 101    Annual Conference on Neural Information Proces...  RC9798641609
# ...                                                  ...           ...
# 10815  Annual Conference on Neural Information Proces...  RC9798641609
# 10824  Annual Conference on Neural Information Proces...  RC9798641609
# 11067       International Conference on Machine Learning  RC6493598945
# 11279  Annual Conference on Neural Information Proces...  RC9798641609
# 12845  Annual Conference on Neural Information Proces...  RC9798641609
#
#                                               Conference  Publication Date  \
# 46     NeurIPS 2020 - 34th Conference on Neural Infor...              2020
# 47     NeurIPS 2020 - 34th Conference on Neural Infor...              2020
# 89     NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# 98     NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# 101    NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# ...                                                  ...               ...
# 10815          NeurIPS 2023 Workshop on Diffusion Models              2023
# 10824  Neural Information Processing Systems (NeurIPS...              2023
# 11067  PMLR 2022 - Proceedings of Machine Learning Re...              2022
# 11279  Proceedings of the Neural Information Processi...              2022
# 12845  Workshop on Robustness in Sequence Modeling, 3...              2022
#
#        Publication Count
# 46                     4
# 47                     3
# 89                     3
# 98                     1
# 101                    1
# ...                  ...
# 10815                  1
# 10824                  1
# 11067                  1
# 11279                  1
# 12845                  1
#
# [101 rows x 5 columns]

# %%
# Vérif
neurips = ml_ia_publications[ml_ia_publications['title'] == 'Annual Conference on Neural Information Processing Systems']
neurips
# Out:
#                                                    title  revconf_siid  \
# 46     Annual Conference on Neural Information Proces...  RC9798641609
# 47     Annual Conference on Neural Information Proces...  RC9798641609
# 89     Annual Conference on Neural Information Proces...  RC9798641609
# 98     Annual Conference on Neural Information Proces...  RC9798641609
# 101    Annual Conference on Neural Information Proces...  RC9798641609
# 128    Annual Conference on Neural Information Proces...  RC9798641609
# 131    Annual Conference on Neural Information Proces...  RC9798641609
# 134    Annual Conference on Neural Information Proces...  RC9798641609
# 300    Annual Conference on Neural Information Proces...  RC9798641609
# 309    Annual Conference on Neural Information Proces...  RC9798641609
# 315    Annual Conference on Neural Information Proces...  RC9798641609
# 318    Annual Conference on Neural Information Proces...  RC9798641609
# 406    Annual Conference on Neural Information Proces...  RC9798641609
# 418    Annual Conference on Neural Information Proces...  RC9798641609
# 422    Annual Conference on Neural Information Proces...  RC9798641609
# 673    Annual Conference on Neural Information Proces...  RC9798641609
# 1283   Annual Conference on Neural Information Proces...  RC9798641609
# 1286   Annual Conference on Neural Information Proces...  RC9798641609
# 1353   Annual Conference on Neural Information Proces...  RC9798641609
# 1355   Annual Conference on Neural Information Proces...  RC9798641609
# 1947   Annual Conference on Neural Information Proces...  RC9798641609
# 1956   Annual Conference on Neural Information Proces...  RC9798641609
# 2040   Annual Conference on Neural Information Proces...  RC9798641609
# 2672   Annual Conference on Neural Information Proces...  RC9798641609
# 2679   Annual Conference on Neural Information Proces...  RC9798641609
# 4351   Annual Conference on Neural Information Proces...  RC9798641609
# 4360   Annual Conference on Neural Information Proces...  RC9798641609
# 4734   Annual Conference on Neural Information Proces...  RC9798641609
# 5211   Annual Conference on Neural Information Proces...  RC9798641609
# 5512   Annual Conference on Neural Information Proces...  RC9798641609
# 5513   Annual Conference on Neural Information Proces...  RC9798641609
# 5547   Annual Conference on Neural Information Proces...  RC9798641609
# 5548   Annual Conference on Neural Information Proces...  RC9798641609
# 6030   Annual Conference on Neural Information Proces...  RC9798641609
# 6031   Annual Conference on Neural Information Proces...  RC9798641609
# 7355   Annual Conference on Neural Information Proces...  RC9798641609
# 10424  Annual Conference on Neural Information Proces...  RC9798641609
# 10537  Annual Conference on Neural Information Proces...  RC9798641609
# 10569  Annual Conference on Neural Information Proces...  RC9798641609
# 10750  Annual Conference on Neural Information Proces...  RC9798641609
# 10753  Annual Conference on Neural Information Proces...  RC9798641609
# 10758  Annual Conference on Neural Information Proces...  RC9798641609
# 10759  Annual Conference on Neural Information Proces...  RC9798641609
# 10760  Annual Conference on Neural Information Proces...  RC9798641609
# 10762  Annual Conference on Neural Information Proces...  RC9798641609
# 10767  Annual Conference on Neural Information Proces...  RC9798641609
# 10768  Annual Conference on Neural Information Proces...  RC9798641609
# 10769  Annual Conference on Neural Information Proces...  RC9798641609
# 10774  Annual Conference on Neural Information Proces...  RC9798641609
# 10779  Annual Conference on Neural Information Proces...  RC9798641609
# 10790  Annual Conference on Neural Information Proces...  RC9798641609
# 10791  Annual Conference on Neural Information Proces...  RC9798641609
# 10796  Annual Conference on Neural Information Proces...  RC9798641609
# 10815  Annual Conference on Neural Information Proces...  RC9798641609
# 10824  Annual Conference on Neural Information Proces...  RC9798641609
# 11279  Annual Conference on Neural Information Proces...  RC9798641609
# 12845  Annual Conference on Neural Information Proces...  RC9798641609
#
#                                               Conference  Publication Date  \
# 46     NeurIPS 2020 - 34th Conference on Neural Infor...              2020
# 47     NeurIPS 2020 - 34th Conference on Neural Infor...              2020
# 89     NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# 98     NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# 101    NeurIPS 2023 - 37th Conference on Neural Infor...              2023
# 128    NeurIPS 2023 – 37th Conference on Neural Infor...              2023
# 131    NeurIPS 2023 – 37th Conference on Neural Infor...              2023
# 134    NeurIPS 2023 – 37th Conference on Neural Infor...              2023
# 300    NeurIPS 2019 - Thirty-third Conference on Neur...              2019
# 309    NeurIPS 2022 - Thirty-sixth Conference on Neur...              2022
# 315    NeurIPS 2022 - Thirty-sixth Conference on Neur...              2022
# 318    NeurIPS 2022 - Thirty-sixth Conference on Neur...              2022
# 406    NeurIPS 2021 - Thirty-fifth Conference on Neur...              2021
# 418    NeurIPS 2022 - 36th Conference on Neural Infor...              2022
# 422    NeurIPS 2022 - 36th Conference on Neural Infor...              2022
# 673    NeurIPS 2021 - 35th Conference on Neural Infor...              2021
# 1283   NeurIPS 2019 - 33th Annual Conference on Neura...              2019
# 1286   NeurIPS 2019 - 33th Annual Conference on Neura...              2019
# 1353   Advances in Neural Information Processing Syst...              2018
# 1355   Advances in Neural Information Processing Syst...              2022
# 1947   NIPS 2018 - Thirty-second Conference on Neural...              2018
# 1956   NeurIPS 2018 - Thirty-second Conference on Neu...              2018
# 2040   35th Conference on Neural Information Processi...              2021
# 2672                                             NeurIPS              2020
# 2679                                        NeurIPS 2021              2021
# 4351   NeurIPS 2020 - 34h Conference on Neural Inform...              2020
# 4360                                        NeurIPS 2022              2022
# 4734   Thirty-sixth Conference on Neural Information ...              2022
# 5211   2022 Conference on Neural Information Processi...              2022
# 5512   32nd Conference on Neural Information Processi...              2018
# 5513   32nd Conference on Neural Information Processi...              2018
# 5547   36th Conference on Neural Information Processi...              2022
# 5548   36th Conference on Neural Information Processi...              2022
# 6030   AI4MAt  2023 - AI for   Accelerated Materials ...              2023
# 6031   AI4MAt 2023 -  workshop on AI for Accelerated ...              2023
# 7355   DLDE-III Workshop in the 37th Conference on Ne...              2022
# 10424  ML4H - Machine Learning for Health workshop at...              2020
# 10537  Machine Learning in Structural Biology worksho...              2023
# 10569                 Medical imaging meets NeurIPS 2021              2021
# 10750  NeurIPS - 34th Conference on Neural Informatio...              2020
# 10753  NeurIPS 2018 (Advances in Neural Information P...              2018
# 10758  NeurIPS 2019 - 33th Annual Conference on Neura...              2019
# 10759  NeurIPS 2019 - 33th Conference on Neural Infor...              2019
# 10760  NeurIPS 2019 - Advances in Neural Information ...              2019
# 10762  NeurIPS 2019 - Neural Information Processing S...              2019
# 10767  NeurIPS 2020 - 34th Conference on Neural Infor...              2020
# 10768  NeurIPS 2020 - 3rd Workshop on Machine Learnin...              2020
# 10769  NeurIPS 2020 - Advances in Neural Information ...              2020
# 10774  NeurIPS 2020 Workshop - Tackling Climate Chang...              2020
# 10779  NeurIPS 2021 - 35th Conference on Neural Infor...              2021
# 10790  NeurIPS 2022 - Conference on Neural Informatio...              2022
# 10791  NeurIPS 2022 - Conference on Neural Informatio...              2022
# 10796  NeurIPS 2022 - the 36th conference on Neural I...              2022
# 10815          NeurIPS 2023 Workshop on Diffusion Models              2023
# 10824  Neural Information Processing Systems (NeurIPS...              2023
# 11279  Proceedings of the Neural Information Processi...              2022
# 12845  Workshop on Robustness in Sequence Modeling, 3...              2022
#
#        Publication Count
# 46                     4
# 47                     3
# 89                     3
# 98                     1
# 101                    1
# 128                    1
# 131                    1
# 134                    1
# 300                    1
# 309                    1
# 315                    1
# 318                    1
# 406                    1
# 418                    2
# 422                    1
# 673                    1
# 1283                   2
# 1286                   1
# 1353                   1
# 1355                   1
# 1947                   1
# 1956                   1
# 2040                   1
# 2672                   1
# 2679                   1
# 4351                   1
# 4360                   1
# 4734                   1
# 5211                   1
# 5512                   1
# 5513                   1
# 5547                   1
# 5548                   1
# 6030                   1
# 6031                   1
# 7355                   1
# 10424                  1
# 10537                  1
# 10569                  1
# 10750                  1
# 10753                  1
# 10758                  1
# 10759                  1
# 10760                  1
# 10762                  1
# 10767                  1
# 10768                  1
# 10769                  1
# 10774                  1
# 10779                  1
# 10790                  1
# 10791                  1
# 10796                  1
# 10815                  1
# 10824                  1
# 11279                  1
# 12845                  1

# %%
# VERIF
# Filtrer les lignes où la 'Publication Date' est 2023
neurips2023 = neurips[neurips['Publication Date'] == 2023]
neurips2023
# Calculer la somme de la colonne 'Publication Count' pour ces lignes filtrées
publication_count_sum = neurips2023['Publication Count'].sum()
publication_count_sum
# Out:
# 13

# %%
pd.set_option('display.max_rows', None) #Permet de voir toutes les lignes

table = pd.pivot_table(ml_ia_publications, values='Publication Count', index=['title'],
                       columns=['Publication Date'], aggfunc="sum")
table.fillna(0, inplace = True)

table['Total'] = table.sum(axis=1)
table
# Out:
# Publication Date                                    2018  2019  2020  2021  \
# title
# Annual Conference on Neural Information Process...   6.0   8.0  15.0   6.0
# International Conference on Artificial Intellig...   1.0   2.0   5.0   2.0
# International Conference on Machine Learning         5.0   4.0   5.0   5.0
# National Conference on Artificial Intelligence       0.0   1.0   1.0   5.0
#
# Publication Date                                    2022  2023  Total
# title
# Annual Conference on Neural Information Process...  18.0  13.0   66.0
# International Conference on Artificial Intellig...   1.0   0.0   11.0
# International Conference on Machine Learning         3.0   5.0   27.0
# National Conference on Artificial Intelligence       1.0   1.0    9.0

# %%
table.to_excel('tableau_confs.xlsx', index=True)

# %%
# api verif:
#  https://api.archives-ouvertes.fr/search/INRIA2?q=neurips&fq=publicationDateY_i:2023%20AND%20docType_s:COMM&fl=uri_s,conferenceTitle_s&rows=70
