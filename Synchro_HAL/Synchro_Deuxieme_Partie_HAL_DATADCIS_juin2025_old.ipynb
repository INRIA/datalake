# %% [markdown]
# # Sychronisation de la copie de HAL
# 1. Identification des notices supprimées depuis la dernière synchro
#     voir script Synchro_Premiere_Partie_HAL_DATADCIS
#
#
#
# 2. Synchronisation de la copie de HAL
#     * API en sortie xml-tei pour rechercher les notices nouvelles et les notices modifiées
#         * C'est le critère "dateLastIndexed_tdate" qui est préféré à "dateModified_tdate" et à "dateReleased_tdate" pour couvrir les notices créées, les notices modifiées et celles qui sont réindexées pour d'autres raisons.
#         * critère : q=dateLastIndexed_tdate:[NOW-1DAY%20TO%20NOW/HOUR]. Explication : [maintenant début de l'heure courante - 1 JOUR (=24h)] JUSQU'A [maintenant début de l'heure courante])
#         * pour info : Pour tester avec dates exactes : api.archives-ouvertes.fr/search/INRIA2?q=dateLastIndexed_tdate:["2024-07-03T15:00:00.224Z"%20TO%20"2024-07-04T16:00:00.224Z"]&rows=1&wt=php&fl=docid,uri_s,dateLastIndexed_tdate&sort=docid%20asc&cursorMark=*
#         * autres critères : rows=1 et cursorMark pour itérer sur chaque notice du résultat
#         * notices
#             * enregistrer chaque notice xml-tei (métadonnés de hal) correspondant à chaque docid (il y a un docid par version, donc cela permet d'enregistrer toutes les versions.
#             * format du nom du fichier : halID_version.xml (exemple : hal-01044648_v1.xml)
#             * dossier de stockage : /data/année/date_du_jour/Notices_Xml-tei_de_Hal
#         * fichiers
#             * Enregistrer uniquement le fichier PDF associé à la notice (l'objectif étant d'en extraire le full text dans un deuxième temps) dans un dossier correspondant à l'année et un sous-dossier correspondant au jour.
#             * Critère d'identification des fichiers dans la notice : existence de balises \<ref\> dans \<edition\>, qui contiennent les liens vers tous les fichiers déposés dans la notice et aussi les liens externalLink
#             * format du nom du fichier : " HALID_version_nom_du_fichier.extension du fichier" . exemple : inria-00441254_v2_NEL-splitting.pdf
#             * exclusion : tout ce qui n'est pas un fichier PDF (page html ou juste "document" (ex: hal-01000423), tout ce qui est ExternalLink (car on ne connaît pas la licence) et tout ce qui est sous embargo.
#             * Embargo : un fichier est créé qui liste les fichiers sous embargo avec la date.
#             * dossier de stockage : ../pdf_de_hal/année/date_du_jour

# %% [markdown]
# ## Synchronisation quotidienne : ajout des notices nouvelles ou modifiées

# %%
###################################################
## Ajout quotidien de notices nouvelles / modifiées,  et de leurs fichiers
#/!\ Retirer le filtre INRIA2 dans base_url pour la mise en prod!
#/!\ retirer la limite à 300 du compteur à la fin pour la mise en prod!
###################################################

import requests
import xml.etree.ElementTree as ET
import time
import logging
import re
import os
import pandas as pd
from datetime import datetime, date
import shutil
import urllib.parse
import openpyxl



# Obtenir la date actuelle
date_extraction_current = datetime.now().strftime("%Y_%m_%d")
annee_current = datetime.now().strftime("%Y")




## Spécifier le répertoire de log
log_directory = '/data/log/'
## Créer le répertoire s'il n'existe pas
os.makedirs(log_directory, exist_ok=True)

# Construire le nom du fichier de log avec le chemin complet
log_file = os.path.join(log_directory, date_extraction_current + '_log_synchro_part2_hal.txt')

# Configuration du logger
logging.basicConfig(filename=log_file, level=logging.INFO, format='%(asctime)s - %(message)s', filemode='w')


# with open(log_file, 'a') as f:
#     f.write("Début du fichier de log.\n")

# URL de base de l'API
base_url = "https://api.archives-ouvertes.fr/search/INRIA"

#Critère : tout ce qui a été indexé les dernières 24H
query = "dateLastIndexed_tdate:[NOW-1DAY TO NOW/HOUR]"

# Paramètres de la requête
params = {
    "wt": "xml-tei",
    "rows": 1,
    "sort": "docid asc"
}

# Définition des variables
embargos = set()

# Définition des compteurs
compteur = 0
affichage = 0
compte_embargo = 0
compte_externalLink = 0
compteur_notices_enregistrees = 0
compteur_telechargements = 0

# Déterminer le chemin du dossier DocidDeHAL (au même niveau que le dossier courant)
docid_folder_xml =f"/data/Notices_Xml-tei_de_Hal/{annee_current}/{date_extraction_current}"
docid_folder_pdf = f"/data/pdf_de_hal/{annee_current}/{date_extraction_current}/" 
# Vérifier que le dossier de sortie existe et le créer si nécessaire
os.makedirs(docid_folder_xml, exist_ok=True)
os.makedirs(docid_folder_pdf, exist_ok=True)

# Initialisation du cursorMark
cursor_mark = "*"
previous_cursor_mark = None

logging.info(f"{base_url}?q={query}&wt={params['wt']}&rows={params['rows']}&sort={params['sort']}&cursorMark={cursor_mark}")


# Définition du namespace
namespaces = {"tei": "http://www.tei-c.org/ns/1.0"}

# Lorsque le cursorMark de la réponse est identique à celui de la requête, c'est qu'on a atteint la dernière notice
while cursor_mark != previous_cursor_mark: # tant que le cursorMark est différent du précédent, on récupère la notice
    compteur += 1
    #print(compteur)
    # Mise à jour du cursorMark
    params["cursorMark"] = cursor_mark # cette valeur est d'abord *, puis la valeur du cursorMark de la requête précédente
    #logging.info(f"CursorMark: {cursor_mark}")

    # construction de l'api (cette méthode évite la transformation des espaces et parenthèses en codes qui génèrent une erreur)
    full_url = f"{base_url}?q={query}&wt={params['wt']}&rows={params['rows']}&sort={params['sort']}&cursorMark={params['cursorMark']}"
    
    # Envoi de la requête GET
    response = requests.get(full_url)

    # Vérification du statut de la réponse
    if response.status_code != 200:
        logging.error(f"Erreur: {response.status_code}")
        break

    # Affichez le contenu de la réponse pour le débogage
    #print(f"Response content:\n{response.content.decode('utf-8')}")

    try:
        # Traitement de la réponse XML
        data = ET.fromstring(response.content)
    except ET.ParseError as e:
        logging.error(f"Erreur de parsing: {e}")
        break

    # Recherche du nombre total de résultats
    total_results = data.find('.//tei:measure[@commodity="totalSearchResults"]', namespaces)
    if total_results is not None and affichage == 0:
        total_quantity = total_results.attrib['quantity']
        affichage += 1
        print(f"Nbre de notices indexées ces dernières 24h: {total_quantity}")
        logging.info(f"Nbre de notices indexées ces dernières 24h: {total_quantity}")

    # Récupération du nouveau cursorMark
    next_cursor_mark = data.attrib.get("next")
    # si pas de cursorMark (en principe, il y en a toujours un), on arrête
    if not next_cursor_mark:
        break


    # Récupération du HalId de la publication
    halID_element = data.find('.//tei:idno[@type="halId"]', namespaces)

    # trouver l'uri:
    uri = data.find('.//tei:idno[@type="halUri"]', namespaces)
    # Trouver la version
    current_edition = data.find('.//tei:edition[@type="current"]', namespaces)

    
    # On exécute jusqu'à ce qu'il n'y ait plus de halID dans la réponse
    if halID_element is not None:
        halID_value = halID_element.text
        print(f"hal ID: {halID_value}")
        # logging.info(f"HAL ID: {halID_value}")
    else:
        logging.error("HAL ID not found")
        break
    
    # Vérifier si la version est indiquée
    if current_edition is not None:
        n_value = current_edition.get('n')
        # logging.info(f'version: {n_value}')
    else:
        n_value = ''

    # Mise à jour du cursorMark pour la prochaine itération
    previous_cursor_mark = cursor_mark
    cursor_mark = next_cursor_mark


#########################################################
# Enregistrement de la notice xml-tei dans un fichier XML
#########################################################
    nom_fichier = os.path.join(docid_folder_xml,f'{halID_value}_{n_value}.xml')
    logging.info(f"notice: {halID_value}_{n_value}.xml'")

    compteur_notices_enregistrees += 1

    with open(nom_fichier, "wb") as f:
        f.write(response.content)



##########################################################
# Fonctions de traitement des noms de fichier
#########################################################

    # Fonction pour nettoyer le nom de fichier
    def clean_filename(filename):
        # Supprimer tout ce qui vient après '?' y compris le '?'
        #exemple : fulltext.pdf?sid=hal --> devient fulltext.pdf
        filename = filename.split('?')[0]
        return filename
    
    # Fonction pour vérifier si le nom de fichier est valide
    def is_valid_filename(filename):
        # Vérifier si le nom de fichier se termine par un point suivi de trois lettres
        return bool(re.match(r'.*\.[a-zA-Z]{3}$', filename))
    
    

######################################################################
# Trouver et enregistrer tous les fichiers PDF associés
# appliquer les mêmes règles pour la section "Embargo" située ensuite
######################################################################

    # Repérer la présence de liens vers des fichiers dans la notice
    refs = data.findall('.//tei:edition[@type="current"]/tei:ref', namespaces)

#     # URL spécifique à exclure (se terminant par /document , qui ne pointe pas vers un fichier)
#     exclude_url_suffix = '/document'
    include_file_extension=("pdf", "PDF")


    # Identifier les sous-éléments de chaque "ref" (lien vers des fichiers)

    for ref in refs:
        ref_type = ref.get('type')
        subtype = ref.get('subtype')
        n = ref.get('n')
        target = ref.get('target') # contient l'url du fichier
        date_tag = ref.find('tei:date', namespaces)
        # print(f"ce ref {ref_type} - {subtype} - {n} - {target} - {date_tag} ")

        telecharge = False

        # On ne télécharge que si l'extension est pdf ou PDF
        if target.endswith(include_file_extension) and ref_type == 'file':
            
            telecharge = True
            #print(f"Target {target} se termine par pdf")

        # identification de la date pour analyse
            if date_tag is not None:
                not_before_date = date_tag.get('notBefore')
                # print(f"not before : {not_before_date}")

                if not_before_date:
                    # Convertir la date au format AAAA-MM-JJ
                    ref_date = datetime.strptime(not_before_date, '%Y-%m-%d').date()
                    #print(ref_date)

                    current_date = date.today()
                    # print(f"date revue: {ref_date} et date du jour : {current_date}")

            # Vérifier que la date n'est pas postérieure à la date actuelle (si oui = sous embargo)
            if ref_date <= current_date:
                # print(f"pas sous embargo")
                embargo = 'False'
                telecharge = 'ok' 
                
            else:
                embargo = 'True'
                if ref_type == 'file':
                    embargomainfile = True
                else:
                    embargomainfile = False
                logging.info(f"embargo à {ref_date} pour {halID_value}")         
                print(f"embargo à {ref_date} pour {halID_value}")         
                # Ajouter les valeurs dans la liste
                if target.endswith(include_file_extension):
                    embargos.add((ref_date, halID_value, embargomainfile, target))
                    print (f" embargo: {ref_date} - {halID_value} - {embargomainfile} - {target}")     
        

            # Extraire le nom de fichier et l'extension
            file_name = os.path.basename(target)
            name, ext = os.path.splitext(file_name)

            # Réduire le nom à 100 caractères en incluant l'extension (certains noms de fichier sont trop long et génèrent une interruption du script)
            max_length = 100
            if len(file_name) > max_length:
                truncated_name = name[:max_length - len(ext)]
                file_name = f"{truncated_name}{ext}"

            #print(f"nom du fichier éventuellement réduit:{file_name}")

            clean_file_name = clean_filename(file_name) #supprime d'éventuelles url se terminant par ?xxx

            if ref_type == 'file':
                pdf_filename = os.path.join(docid_folder_pdf, f"{halID_value}_{n_value}_main_{clean_file_name}")
                #print(f"nom du fichier : {halID_value} subtype : {subtype} main: {pdf_filename}")
            else:
                pdf_filename = os.path.join(docid_folder_pdf, f"{halID_value}_{n_value}_{clean_file_name}")
                #print(f"nom du fichier pas 'file' {halID_value} subtype : {subtype} pas main: {pdf_filename}")

            # Enregistrement du pdf
            uri = target
            if is_valid_filename(pdf_filename): # on vérifie que c'est bien un nom de fichier pour éviter les urls qui renvoient sur une page html (ex: elsevier)
                try:
                    response = requests.get(uri)
                    response.raise_for_status()  # Vérifie si la requête a échoué
                    with open(pdf_filename, 'wb') as pdf_file:
                        pdf_file.write(response.content)
                        compteur_telechargements += 1
                        print(f'Téléchargé: {pdf_filename}')
                        logging.info(f'fichier: {halID_value}_{n_value}_{clean_file_name}')
                except requests.exceptions.RequestException as e:
                    logging.error(f'Échec du téléchargement pour {halID_value}{n_value} - {ref_type} - {date_tag} - {uri}: {e}')
                except OSError as e:
                    logging.error(f'OSError lors de l\'enregistrement du fichier {pdf_filename}: {e}')
                    continue  # Passer à l'itération suivante en cas d'erreur OSError
                except Exception as e:
                    logging.error(f'Erreur inattendue pour {uri}: {e}')
                    continue  # Passer à l'itération suivante en cas d'erreur inattendue


        #else:
            #print(f"Target {target} ne se termine pas par pdf")

#     # Pause pour éviter de surcharger l'API
#     time.sleep(0.1)

    #limite pour tests
    # if compteur >= 100:
    #     break

print(f"Liste des embargos : {embargos}")  # Cette ligne est pour le débogage

compte_embargo = len(embargos)

# Chemin du fichier Embargos.xlsx
embargo_file_path = "/data/log/Embargos.xlsx"

# Vérifier si le fichier Embargos.xlsx existe déjà
if os.path.exists(embargo_file_path):
    # Charger le fichier Excel existant
    df_existing = pd.read_excel(embargo_file_path)
    
    # Créer un DataFrame pour les nouvelles données
    df_new = pd.DataFrame(embargos, columns=['ref_date', 'halID_value','embargomainfile', 'target'])
    
    # Ajouter les nouvelles données au DataFrame existant
    df_combined = pd.concat([df_existing, df_new], ignore_index=True)
else:
    # Créer un nouveau DataFrame avec les nouvelles données
    df_combined = pd.DataFrame(embargos, columns=['ref_date', 'halID_value','embargomainfile', 'target'])

# Enregistrer les données combinées dans Embargos.xlsx
df_combined.to_excel(embargo_file_path, index=False)



logging.info(f"notices sous embargo : {compte_embargo}")
logging.info(f"nbre notices xml enregistrées : {compteur_notices_enregistrees}")
logging.info(f"nbre de fichiers enregistrés : {compteur_telechargements}")

print(f"notices sous embargo : {compte_embargo}")
print(f"nbre notices xml enregistrées : {compteur_notices_enregistrees}")
print(f"nbre de fichiers enregistrés : {compteur_telechargements}")


logging.info("Synchro 2e partie terminée.")
print("Synchro 2e partie terminée.")
# Out:
# Nbre de notices indexées ces dernières 24h: 2301
# hal ID: hal-01001975
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01001975_v1_main_art.pdf
# hal ID: hal-01006397
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01006397_v1_main_paper.pdf
# hal ID: hal-01007645
# hal ID: hal-01007664
# hal ID: hal-01007689
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01007689_v1_main_grizou2014interactive.pdf
# hal ID: hal-01008646
# hal ID: hal-01008796
# hal ID: hal-01008838
# hal ID: hal-01009837
# hal ID: hal-01009853
# hal ID: hal-01010087
# hal ID: hal-01010096
# hal ID: hal-01010193
# hal ID: hal-01010197
# hal ID: hal-01010215
# hal ID: hal-01010335
# hal ID: hal-01010356
# hal ID: hal-01010373
# hal ID: hal-01010389
# hal ID: hal-01010396
# hal ID: hal-01010405
# hal ID: hal-01010417
# hal ID: hal-01010426
# hal ID: hal-01010610
# hal ID: hal-01010667
# hal ID: hal-01010719
# hal ID: hal-01010720
# hal ID: hal-01010723
# hal ID: hal-01010725
# hal ID: hal-01010726
# hal ID: hal-01010733
# hal ID: hal-01010735
# hal ID: hal-01010737
# hal ID: hal-01010739
# hal ID: hal-01012078
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01012078_v1_main_Armand_IV14.pdf
# hal ID: hal-01012090
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01012090_v1_main_paper_submitted.pdf
# hal ID: hal-01015907
# hal ID: hal-01015921
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01015921_v1_main_tapus_ISRR2003.pdf
# hal ID: hal-01016428
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01016428_v1_main_edm14mainshortLETTER.pdf
# hal ID: hal-00955921
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00955921_v2_main_Infinite_Horizon_Problems_on_Stratifiable_State_Constraints_sets.pdf
# hal ID: pastel-01023289
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/pastel-01023289_v1_main_Manuscrit.pdf
# hal ID: hal-01023615
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01023615_v1_main_a_multi_modal_system_for_road_detection_and_segmentation.pdf
# hal ID: hal-01024111
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01024111_v1_main_Aronna-NETCO.pdf
# hal ID: hal-01024231
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01024231_v1_main_Bonnans-NETCO2014.pdf
# hal ID: hal-01024622
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01024622_v1_main_Hermosilla-NETCO2014.pdf
# hal ID: hal-01024628
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01024628_v1_main_Jean-NETCO2014.pdf
# hal ID: hal-00989492
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00989492_v2_main_Ferretti-Zidani_Hal-V2.pdf
# hal ID: hal-01054389
# hal ID: hal-01059411
# hal ID: hal-00914674
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00914674_v2_main_article_bourgeois_fliss_rev_cor.pdf
# hal ID: tel-01060178
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01060178_v1_main_VD2_BUREL_ALIENOR_04072014.pdf
# hal ID: hal-01061211
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061211_v1_main_DI2014_kidlearn.pdf
# hal ID: hal-01061406
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061406_v1_main_Duceux_IROS14.pdf
# hal ID: hal-01061633
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061633_v1_main_OudeyerSIAMNews14.pdf
# hal ID: hal-01061654
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061654_v1_main_article.pdf
# hal ID: hal-01061662
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061662_v1_main_final_article.pdf
# hal ID: hal-01061668
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061668_v1_main_finalarticle.pdf
# hal ID: hal-01061682
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061682_v1_main_brice-icdl.pdf
# hal ID: hal-01061708
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061708_v1_main_icdl2014_cmf_pr_pyo.pdf
# hal ID: hal-01061195
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01061195_v2_main_14icdl_kidlearn_final.pdf
# hal ID: hal-01063139
# hal ID: hal-01064430
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01064430_v1_main_doc00019289.pdf
# hal ID: hal-01064517
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01064517_v1_main_doc00019297.pdf
# hal ID: hal-01064727
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01064727_v1_main_doc00019295.pdf
# hal ID: hal-01060601
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01060601_v2_main_RR-8584.pdf
# hal ID: hal-01067112
# hal ID: hal-01069252
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01069252_v1_main_Wm3-V1.pdf
# hal ID: hal-01069808
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01069808_v1_main_Asynchronous_tracker.pdf
# hal ID: hal-01072784
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01072784_v1_main_A_Armand_SMC_final.pdf
# hal ID: hal-01073947
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01073947_v1_main_WACAI_2014_OPML.pdf
# hal ID: hal-01074822
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01074822_v1_main_paper.pdf
# hal ID: hal-01082068
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01082068_v1_main_eabe14.pdf
# hal ID: hal-01083772
# hal ID: hal-01085477
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01085477_v1_main_SubM2AN_author.pdf
# hal ID: hal-01087227
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01087227_v1_main_fnins-08-00317.pdf
# hal ID: hal-01087392
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01087392_v1_main_acvr2014_CaronEtAl.pdf
# hal ID: hal-01088999
# hal ID: hal-01089097
# hal ID: hal-01089099
# hal ID: hal-01090084
# hal ID: hal-01090481
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01090481_v1_main_DCDS-S_Joly.pdf
# hal ID: hal-01090848
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01090848_v1_main_jfpda2014.pdf
# hal ID: hal-01090934
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01090934_v1_main_avollmer_ICDL2014.pdf
# hal ID: hal-01091145
# hal ID: hal-01091300
# hal ID: hal-01091411
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01091411_v1_main_Est1-V1.pdf
# hal ID: hal-01092658
# hal ID: hal-01094428
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01094428_v1_main_1401.2146v1.pdf
# hal ID: hal-01094807
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01094807_v1_main_cans-final.pdf
# hal ID: hal-01095305
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01095305_v1_main_profiling-memory.pdf
# hal ID: hal-01095703
# hal ID: hal-01089887
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01089887_v1_main_Kalise_Kroener_2014_proceedings.pdf
# hal ID: hal-01089877
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01089877_v1_main_FalconeKaliseKroener2014.pdf
# hal ID: hal-01089336
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01089336_v2_main_kroenerkunisch2013.pdf
# hal ID: hal-01096094
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01096094_v1_main_Romeo2_perception_AIC_2014_Camera_Ready_Final.pdf
# hal ID: hal-01096338
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01096338_v1_main_di2014.pdf
# hal ID: hal-01096344
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01096344_v1_main_humanoids2014.pdf
# hal ID: hal-01090900
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01090900_v1_main_poster_Kidlearn.pdf
# hal ID: hal-01098040
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098040_v1_main_firl.pdf
# hal ID: hal-01098695
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098695_v1_main_kopinski2014c.pdf
# hal ID: hal-01098697
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098697_v1_main_kopinski2014neural.pdf
# hal ID: hal-01098699
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098699_v1_main_gepperth2014latencyc.pdf
# hal ID: hal-01098700
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098700_v1_main_kopinski2014real.pdf
# hal ID: hal-01098701
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098701_v2_main_sattarov2014context.pdf
# hal ID: hal-01098703
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098703_v1_main_gepperth2014robust.pdf
# hal ID: hal-01098704
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098704_v1_main_gepperth2014latency.pdf
# hal ID: hal-01098707
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098707_v1_main_hecht2014scene.pdf
# hal ID: hal-01099016
# hal ID: hal-01099134
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01099134_v1_main_jfla15_submission_22.pdf
# hal ID: hal-01100042
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01100042_v1_main_emergent_maturation_vocal.pdf
# hal ID: hal-01101875
# hal ID: hal-01103010
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01103010_v1_main_pjbr-2014-0005.pdf
# hal ID: hal-01103809
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01103809_v1_main_BlackSea_2013.pdf
# hal ID: hal-01104629
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01104629_v1_main_RR-v2-2.pdf
# hal ID: hal-01107240
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01107240_v1_main_WhatDoWeLearnFromBabyRobotsOudeyer2015.pdf
# hal ID: hal-01109534
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01109534_v1_main_BoCNRevised.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01109534_v1_main_FarField.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01109534_v1_main_Iterations.pdf
# hal ID: hal-01109954
# hal ID: hal-01110485
# hal ID: hal-01110494
# hal ID: hal-01110763
# hal ID: hal-01111101
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01111101_v1_main_fehmm_helmholtz_submitted.pdf
# hal ID: hal-01111169
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01111169_v1_main_Preprint_1325.pdf
# hal ID: hal-01111694
# hal ID: hal-01111966
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01111966_v1_main_rtpm.pdf
# hal ID: hal-01112201
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01112201_v1_main_CiWZ14_Jr.pdf
# hal ID: hal-01113088
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01113088_v1_main_vidrascu_plenary.pdf
# hal ID: hal-01113869
# hal ID: tel-01114368
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01114368_v1_main_these_vigneron.pdf
# hal ID: hal-01114632
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01114632_v1_main_BBDNaTa-HAL.pdf
# hal ID: hal-01114791
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01114791_v1_main_proc_author.pdf
# hal ID: hal-01116024
# hal ID: hal-01116028
# hal ID: hal-01116476
# hal ID: hal-01116493
# hal ID: hal-01116505
# hal ID: hal-01116509
# hal ID: hal-01116516
# hal ID: hal-01116523
# hal ID: hal-01116526
# hal ID: hal-01116531
# hal ID: hal-01116708
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01116708_v1_main_ip14_mece.pdf
# hal ID: hal-01120450
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01120450_v1_main_KaliseKroenerKunisch2015.pdf
# hal ID: hal-01121687
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01121687_v1_main_RR_8692.pdf
# hal ID: hal-01122023
# hal ID: tel-01122262
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01122262_v1_main_thesis-cagdas-bozman.pdf
# hal ID: hal-00950107
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00950107_v2_main_td_stress.pdf
# hal ID: hal-00757005
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00757005_v2_main_inclusionsoft.pdf
# hal ID: hal-01133647
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01133647_v1_main_sidlof_etal_acm2010.pdf
# hal ID: hal-01134006
# hal ID: hal-01135775
# hal ID: hal-01137582
# hal ID: hal-01139397
# hal ID: hal-01139400
# hal ID: hal-01087442
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01087442_v1_main_date2015_moccml.pdf
# hal ID: hal-01144401
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01144401_v1_main_m2an_final.pdf
# hal ID: hal-01144435
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01144435_v1_main_RIE2015_inirobot_inria_epfl_v2.pdf
# hal ID: tel-01145588
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01145588_v1_main_Thesis.pdf
# hal ID: hal-01145601
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01145601_v1_main_Hal.pdf
# hal ID: tel-01148936
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01148936_v1_main_MANGIN_OLIVIER_2014.pdf
# hal ID: hal-00918498
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00918498_v4_main_RR-8425.pdf
# hal ID: hal-01082445
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01082445_v4_main_proc155006%20%282%29.pdf
# hal ID: hal-01153568
# hal ID: hal-01154010
# hal ID: hal-01154119
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01154119_v1_main_chaillat_collino.pdf
# hal ID: hal-01154650
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01154650_v1_main_IJCAI2015_HAL.pdf
# hal ID: hal-01154767
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01154767_v1_main_When%20sharing%20computer%20science%20with%20everyone%20also%20helps%20avoiding%20digital%20prej.pdf
# hal ID: hal-01160157
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01160157_v1_main_DupontEtAl_CapsuleWithBending_POF2015.pdf
# hal ID: hal-01160242
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01160242_v1_main_Rellich-HAL.pdf
# hal ID: hal-01160665
# hal ID: hal-01160896
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01160896_v1_main_CCSS-HAL%20%281%29.pdf
# hal ID: hal-01161848
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01161848_v1_main_V3ORASIS.pdf
# hal ID: hal-01086033
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01086033_v2_main_fliss_joly2015_final.pdf
# hal ID: hal-00116498
# hal ID: hal-01166110
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01166110_v1_main_Lyubova_Auro_2015.pdf
# hal ID: hal-01166961
# hal ID: hal-01166967
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01166967_v1_main_DupontEtAl_CapsBendResist_Hyperbol_ProcediaIUTAM15.pdf
# hal ID: hal-01170532
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01170532_v1_main_ICDL_celine_craye_final.pdf
# hal ID: tel-01170583
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01170583_v1_main_Manuscrit.pdf
# hal ID: hal-01170674
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01170674_v1_main_Chen_ICDL15_final.pdf
# hal ID: tel-01104641
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01104641_v3_main_LAPEYRE_MATTHIEU_2014.pdf
# hal ID: tel-01128691
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01128691_v2_main_Dissertation.pdf
# hal ID: hal-01183511
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01183511_v1_main_cmame15.pdf
# hal ID: hal-01184110
# hal ID: hal-01187242
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01187242_v1_main_chaillat_darbas_lelouer_2015.pdf
# hal ID: hal-01093229
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01093229_v2_main_ErrorEstimRevision.pdf
# hal ID: hal-01188935
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01188935_v1_main_ieee.pdf
# hal ID: hal-01185912
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01185912_v1_main_GarckeKroener2015.pdf
# hal ID: hal-01194742
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01194742_v1_main_NININ_CHABERT.pdf
# hal ID: tel-01095562
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01095562_v3_main_GRIZOU_JONATHAN_2014.pdf
# hal ID: hal-01202654
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01202654_v1_main_main.pdf
# hal ID: hal-01203350
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01203350_v1_main_15learning.pdf
# hal ID: hal-01203505
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01203505_v1_main_ML_deps_assess.pdf
# hal ID: hal-01205611
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01205611_v1_main_finalarticle.pdf
# hal ID: hal-01205619
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01205619_v1_main_finalarticle.pdf
# hal ID: hal-01207334
# hal ID: hal-01215563
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01215563_v1_main_paper.pdf
# hal ID: hal-01137529
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01137529_v3_main_journal.pone.0140732.pdf
# hal ID: hal-01225313
# hal ID: hal-01230175
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01230175_v1_main_moulinfrier2015cosmo.pdf
# hal ID: hal-01231795
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01231795_v1_main_2015_10_06_RCAM_Simka.pdf
# hal ID: hal-01233994
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01233994_v1_main_burton_cl_v6.pdf
# hal ID: hal-01235099
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01235099_v1_main_article_1d_rev.pdf
# hal ID: hal-01235285
# hal ID: hal-01235291
# hal ID: hal-01235292
# hal ID: hal-01235295
# hal ID: hal-01089893
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01089893_v1_main_Kroener_Rodrigues_2015.pdf
# hal ID: hal-01176476
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01176476_v4_main_Jr15_EdgeElts_Part1-final.pdf
# hal ID: hal-01195869
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01195869_v2_main_DtN%20op%20for%20diffraction%20prob%20in%20stratified%20anisotropic%20acoustic%20waveguides.pdf
# hal ID: hal-01239305
# hal ID: hal-01239310
# hal ID: hal-01239315
# hal ID: hal-01240377
# hal ID: hal-01240378
# hal ID: tel-01240904
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01240904_v1_main_These_carvalho.pdf
# hal ID: hal-01125667
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01125667_v2_main_cesar.pdf
# hal ID: hal-01162404
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01162404_v3_main_TechnicalReportEvent.pdf
# hal ID: hal-01242842
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01242842_v1_main_prop_hamze.pdf
# hal ID: hal-01242851
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01242851_v1_main_EMBC%202015%20submission.pdf
# hal ID: hal-01246135
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01246135_v1_main_eivol_jiea.pdf
# hal ID: hal-01246812
# hal ID: hal-01247652
# hal ID: hal-01248283
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01248283_v1_main_A_general_optimal_multiple_stopping_problem_with_an_application_to_Swing_Options_final.pdf
# hal ID: hal-01248282
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01248282_v1_main_Numerical_methods_for_an_optimal_multiple_stopping_problem_Jul_2015.pdf
# hal ID: hal-01248385
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01248385_v1_main_11%20Computer%20Communications%202008.pdf
# hal ID: hal-01249226
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01249226_v1_main_socialrobotics.pdf
# hal ID: hal-01144515
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01144515_v2_main_tice2014_droy_inria_v2.pdf
# hal ID: hal-00998525
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00998525_v1_main_Munoz%20OED_vfinal.pdf
# hal ID: hal-01250424
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01250424_v1_main_poster.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01250424_v1_main_abstract.pdf
# hal ID: hal-01250693
# hal ID: hal-01250727
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01250727_v1_main_curiosityEyeMovementVisResearch15.pdf
# hal ID: hal-01250777
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01250777_v1_main_OudeyerJPhonetics15.pdf
# hal ID: hal-01250781
# hal ID: hal-01250784
# hal ID: hal-01170974
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01170974_v1_main_15-IROS-Raiola.pdf
# hal ID: hal-01250101
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01250101_v1_main_15-MSC.pdf
# hal ID: hal-01170977
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01170977_v1_main_iros2015.pdf
# hal ID: hal-01250961
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01250961_v1_main_gepperth2015biologically.pdf
# hal ID: hal-01250967
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01250967_v1_main_icdl15.pdf
# hal ID: hal-01251009
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01251009_v1_main_esannV2.pdf
# hal ID: hal-01251011
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01251011_v1_main_lefort2015using.pdf
# hal ID: hal-01251015
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01251015_v1_main_gepperth2015ressource.pdf
# hal ID: hal-01251060
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01251060_v1_main_BenureauOudeyerIcdl2015.pdf
# hal ID: hal-01251382
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01251382_v1_main_root.pdf
# hal ID: hal-01251413
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01251413_v1_main_root.pdf
# hal ID: tel-01251481
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01251481_v1_main_main.pdf
# hal ID: hal-01098501
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01098501_v2_main_GMZ_rev2.pdf
# hal ID: hal-00913669
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00913669_v1_main_111-768-1-PB.pdf
# hal ID: hal-01246436
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01246436_v1_main_15-PLOS-uncBCI.pdf
# hal ID: hal-01246455
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01246455_v1_main_paper.pdf
# hal ID: tel-01252695
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01252695_v1_main_doctorat_Didier_Roy_memoire_activites3.pdf
# hal ID: tel-01252831
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01252831_v1_main_phd_final_duceux.pdf
# hal ID: hal-01253166
# hal ID: hal-01162281
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01162281_v2_main_hal-01162281-v2.pdf
# hal ID: hal-01254961
# hal ID: tel-01251324
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01251324_v2_main_BENUREAU_FABIEN_2015.pdf
# hal ID: hal-00979007
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00979007_v2_main_arima00506.pdf
# hal ID: hal-01263455
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01263455_v1_main_arima00508.pdf
# hal ID: hal-01263535
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01263535_v1_main_didapro6_inria_droy_inirobot_poppy_light.pdf
# hal ID: hal-01122633
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01122633_v1_main_Bazeille_2015.pdf
# hal ID: hal-01266862
# hal ID: hal-01084428
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01084428_v2_main_YJFAN_7429-fin.pdf
# hal ID: hal-01164794
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01164794_v3_main_article_WM_V3.pdf
# hal ID: hal-01277412
# hal ID: hal-01278372
# hal ID: hal-01287023
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01287023_v1_main_RR-8882.pdf
# hal ID: hal-01289159
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01289159_v1_main_root.pdf
# hal ID: hal-01292529
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01292529_v1_main_root.pdf
# hal ID: hal-00129758
# hal ID: hal-00129773
# hal ID: hal-01298878
# hal ID: hal-01298988
# hal ID: hal-01300091
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01300091_v1_main_Vol.18.pp.37-51.pdf
# hal ID: hal-01055917
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01055917_v2_main_Legendre.pdf
# hal ID: hal-01239931
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01239931_v2_main_RR-8824.pdf
# hal ID: hal-00798363
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00798363_v3_main_CDC-final.pdf
# hal ID: hal-01309474
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01309474_v1_main_Abstract.pdf
# hal ID: hal-01310387
# hal ID: hal-01310388
# hal ID: hal-01310493
# hal ID: hal-01313601
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01313601_v1_main_1512.03201v1.pdf
# hal ID: hal-01319046
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01319046_v1_main_IV2016_0333_FI.pdf
# hal ID: hal-01323156
# hal ID: hal-01323162
# hal ID: hal-01323186
# hal ID: hal-01323199
# hal ID: hal-01323213
# hal ID: hal-01323225
# hal ID: hal-01323282
# hal ID: hal-01323305
# hal ID: hal-01323310
# hal ID: hal-01323316
# hal ID: hal-01333032
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01333032_v1_main_main.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01333032_v1_main_poster.pdf
# hal ID: tel-00004880
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-00004880_v2_main_HDR-becache.pdf
# hal ID: hal-01336835
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01336835_v1_main_ieee_sor.pdf
# hal ID: hal-01343121
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01343121_v1_main_Jobim2016_amplicon_VFproceedings.pdf
# hal ID: hal-01350157
# hal ID: hal-01350304
# hal ID: hal-01350319
# hal ID: hal-01350357
# hal ID: hal-01350358
# hal ID: hal-01350454
# hal ID: hal-01354013
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01354013_v1_main_paper0325.pdf
# hal ID: tel-01243663
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01243663_v2_main_43170_MARMORAT_2015_archivage.pdf
# hal ID: hal-01225309
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_BCCC16arxiv.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_Dissip.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_domain0.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_energy_compa_pis6_corners_om11.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_energy_compa_pis6_corners_om9_200pts.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_energy_compa_pis6_om11.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_energy_compa_pis6_om9_200pts.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_figs_mesh_1.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_figs_mesh_Euler.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_geometries.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_intro_euler_sym.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_spectre_DIC_5pis12_ND3.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_spectre_DIC_5pis12_ND4.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01225309_v2_main_spectre_HIC_5pis12_ND3.pdf
# hal ID: hal-01358724
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01358724_v1_main_BSSA_aggravation3D_final_R2_simple.pdf
# hal ID: hal-01273496
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01273496_v2_main_ABK-partone-HAL-v2.pdf
# hal ID: hal-01360338
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01360338_v1_main_edm2016.pdf
# hal ID: hal-01363149
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01363149_v1_main_stabMixed.pdf
# hal ID: hal-01366850
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01366850_v2_main_ext_app_heat_eq.pdf
# hal ID: hal-01370820
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01370820_v1_main_Matricon_ICDL16_final.pdf
# hal ID: hal-01370850
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01370850_v1_main_Craye_ICDL16_final.pdf
# hal ID: hal-01370853
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01370853_v1_main_Chen_ICDL16_final.pdf
# hal ID: hal-01376455
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01376455_v1_main_fnbot-10-00010.pdf
# hal ID: hal-01364782
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01364782_v2_main_fehmmMaxwell.pdf
# hal ID: hal-01377998
# hal ID: hal-01379118
# hal ID: hal-01379890
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01379890_v1_main_article1_rev2.pdf
# hal ID: hal-01191755
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01191755_v1_main_Brajard-EGU-2015.pdf
# hal ID: hal-01383074
# hal ID: hal-01383266
# hal ID: hal-01384427
# hal ID: hal-01384562
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01384562_v1_main_Forestier2016Overlapping.pdf
# hal ID: hal-01384566
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01384566_v1_main_Forestier2016Modular.pdf
# hal ID: hal-01384649
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01384649_v1_main_Apprendre%20a%CC%80%20programmer%20Poppy%20Ergo%20Jr%20en%20Snap%21.pdf
# hal ID: hal-01388606
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01388606_v1_main_abstract.pdf
# hal ID: hal-01388731
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01388731_v1_main_BonnetCornaggiaWAVES2015.pdf
# hal ID: hal-01390692
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01390692_v1_main_Vioado.pdf
# hal ID: hal-01396076
# hal ID: hal-01396078
# hal ID: hal-01396079
# hal ID: hal-01396081
# hal ID: inria-00139273
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/inria-00139273_v2_main_RR-6157.pdf
# hal ID: hal-01392947
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01392947_v2_main_root.pdf
# hal ID: hal-01397581
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01397581_v1_main_main.pdf
# hal ID: hal-01398379
# hal ID: hal-01399247
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01399247_v1_main_16-toussaint-ICRA.pdf
# hal ID: hal-01402479
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01402479_v1_main_multimodal-dataset-nips%281%29.pdf
# hal ID: hal-01402493
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01402493_v1_main_multimodal-dataset-interactive.pdf
# hal ID: hal-00140349
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00140349_v1_main_ABGHR_HAL.pdf
# hal ID: hal-01404278
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404278_v1_main_oudeyerGottliebLopesPBR16Preprint.pdf
# hal ID: hal-01404304
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404304_v1_main_oudeyeretalERCIM16.pdf
# hal ID: hal-01404329
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404329_v1_main_frontiersBenureauOudeyer16.pdf
# hal ID: hal-01404334
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404334_v1_main_OudeyerSmithTopicsCogSci14.pdf
# hal ID: hal-01404385
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404385_v1_main_rohlfingetalFrontiers16.pdf
# hal ID: hal-01404432
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404432_v1_main_oudeyerMachinesRobots123Codez.pdf
# hal ID: hal-01404458
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404458_v1_main_CDSNL-V13-N1.pdf
# hal ID: hal-01404468
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404468_v1_main_GottliebOudeyerLopes_IntrinsicMotivationHAL.pdf
# hal ID: hal-01404486
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404486_v1_main_NewMLE.pdf
# hal ID: hal-01404503
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01404503_v1_main_SFR18Pezzuloetal.pdf
# hal ID: hal-01406597
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01406597_v1_main_BioRob_Final.pdf
# hal ID: hal-01402517
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01402517_v1_main_1089.pdf
# hal ID: hal-01408817
# hal ID: hal-01408836
# hal ID: hal-01408875
# hal ID: hal-01408885
# hal ID: hal-01408897
# hal ID: hal-01412396
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01412396_v1_main_DelourmeJolyVasilevskayaGraphe3D.pdf
# hal ID: hal-01412928
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01412928_v1_main_inirobot.pdf
# hal ID: hal-01412960
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01412960_v1_main_HEPS2016_Delmas.pdf
# hal ID: hal-01406544
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01406544_v2_main_PI_ibridi_v7_arxiv.pdf
# hal ID: hal-01413043
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01413043_v1_main_article.pdf
# hal ID: hal-01413061
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01413061_v1_main_OUD_2016_paper_2.pdf
# hal ID: hal-01413159
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01413159_v1_main_liftedPoR.pdf
# hal ID: hal-01413294
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01413294_v1_main_ocaml2014_14.pdf
# hal ID: hal-01413319
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01413319_v1_main_OCaml_2015_submission_3.pdf
# hal ID: tel-01395525
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01395525_v2_main_Cornaggia_Thesis_131216.pdf
# hal ID: hal-01417944
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01417944_v1_main_jiea16.pdf
# hal ID: hal-01418123
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418123_v1_main_article.pdf
# hal ID: hal-01418125
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418125_v1_main_article.pdf
# hal ID: hal-01418128
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418128_v1_main_paper.pdf
# hal ID: hal-01418129
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418129_v1_main_article.pdf
# hal ID: hal-01418132
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418132_v1_main_article.pdf
# hal ID: hal-01418135
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418135_v1_main_article_ICANN16.pdf
# hal ID: hal-01418137
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418137_v1_main_main.pdf
# hal ID: hal-01418141
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418141_v1_main_root.pdf
# hal ID: tel-01418147
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01418147_v1_main_hdr.pdf
# hal ID: hal-01418160
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01418160_v1_main_karaoguz_2016_itsc_submission.pdf
# hal ID: tel-01421740
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01421740_v1_main_53580_BECK_2016_archivage.pdf
# hal ID: tel-01421917
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01421917_v1_main_46390_ARMAND_2016_archivage.pdf
# hal ID: tel-01421937
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01421937_v1_main_these_chamaillard.pdf
# hal ID: tel-01422039
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01422039_v2_main_59089_BAKRY_2016_archivage.pdf
# hal ID: tel-01426166
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01426166_v1_main_These.pdf
# hal ID: tel-01426226
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01426226_v1_main_52423_VINOLES_2016_archivage.pdf
# hal ID: hal-01414781
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01414781_v2_main_RR-9005.pdf
# hal ID: inria-00143515
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/inria-00143515_v2_main_RR-6170.pdf
# hal ID: hal-01378501
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01378501_v2_main_PreprintPMLconvex_FINAL.pdf
# hal ID: tel-01444540
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01444540_v1_main_manuscrit.pdf
# hal ID: hal-01451126
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01451126_v1_main_PRL16.pdf
# hal ID: hal-00145454
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00145454_v1_main_safe_unmarshalling.pdf
# hal ID: hal-01408294
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01408294_v1_main_GeneralMarkovGamesHAL.pdf
# hal ID: hal-01346096
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01346096_v2_main_doc00021512.pdf
# hal ID: hal-01009815
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01009815_v1_main_00_SIAP.pdf
# hal ID: hal-01009269
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01009269_v1_main_BonRamTil_CRAS.pdf
# hal ID: hal-00990209
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00990209_v1_main_02_M2AN.pdf
# hal ID: hal-01433841
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01433841_v2_main_a_post_elast.pdf
# hal ID: hal-01366646
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01366646_v2_main_biot_aposteriori.pdf
# hal ID: hal-01474045
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01474045_v1_main_Integration_Methods_and_Accelerated_Optimization_Algorithms.pdf
# hal ID: hal-01474362
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01474362_v1_main_Sharpness_Restart_Acceleration_arxiv.pdf
# hal ID: hal-01475251
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01475251_v1_main_paper_6-4.pdf
# hal ID: hal-00852248
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-00852248_v2_main_qjmam_rev.pdf
# hal ID: hal-01419682
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01419682_v2_main_main_report%20%281%29.pdf
# hal ID: inria-00148395
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/inria-00148395_v2_main_RR-6195.pdf
# hal ID: hal-01488172
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01488172_v1_main_CiDS17_HAL.pdf
# hal ID: inria-00148946
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/inria-00148946_v2_main_RR-6199.pdf
# hal ID: hal-01490406
# hal ID: inria-00149411
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/inria-00149411_v2_main_RR-6200.pdf
# hal ID: hal-01493576
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01493576_v1_main_root-hal.pdf
# hal ID: hal-01499498
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01499498_v1_main_m2an16.pdf
# hal ID: hal-01222752
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01222752_v1_main_Introduction_SI_final.pdf
# hal ID: hal-01312801
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01312801_v3_main_Wm5.pdf
# hal ID: hal-01507063
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01507063_v1_main_paper_kde.pdf
# hal ID: medihal-01476320
# hal ID: hal-01516460
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01516460_v1_main_r_8H554245.pdf
# hal ID: hal-01517930
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01517930_v1_main_inirobot_poppy_mathematice_didier_roy_avril2017.pdf
# hal ID: hal-01523020
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01523020_v1_main_chaillat_2017.pdf
# hal ID: tel-01526955
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01526955_v1_main_MUNZER_THIBAUT_2017.pdf
# hal ID: hal-01517941
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01517941_v2_main_Inria_flowers_Poppy_EIAH2017v2.pdf
# hal ID: tel-02796455
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-02796455_v2_main_2016NICE4024.pdf
# hal ID: hal-01529185
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01529185_v1_main_bec-jol-scar.pdf
# hal ID: cel-01529234
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/cel-01529234_v1_main_joly95.pdf
# hal ID: cel-01529244
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/cel-01529244_v1_main_cours_eqinteg.pdf
# hal ID: hal-01530977
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01530977_v1_main_real-time-distributed_final.pdf
# hal ID: tel-01534930
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01534930_v1_main_BLANCHARD_PIERRE_2017.pdf
# hal ID: hal-01536557
# hal ID: hal-01547364
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01547364_v1_main_metamaterials_2017_Ciarlet_rev.pdf
# hal ID: hal-01327315
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01327315_v3_main_article.pdf
# hal ID: hal-01563505
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01563505_v1_main_17-EG3DOR-SHREC-Hand-Gesture-DeSmedt.pdf
# hal ID: hal-01564093
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01564093_v1_main_amplicons_PeerJ_20170718.pdf
# hal ID: hal-01349385
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01349385_v4_main_CiJK17.pdf
# hal ID: hal-01567236
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01567236_v1_main_2017_IROS_Azagra_FinalVersion.pdf
# hal ID: hal-01571391
# hal ID: hal-01573689
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01573689_v1_main_Modave2017_ProcWavesConf.pdf
# hal ID: tel-01573831
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/tel-01573831_v1_main_54542_CORNAGGIA_2016_archivage.pdf
# hal ID: hal-01575355
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01575355_v1_main_Measuring-models-in-Model-Driven-Software-Development-Integrating-Quality-Assurance.pdf
# hal ID: hal-01576304
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01576304_v1_main_RCAM2016_long_DetectionOfMutatedPrimers_20170822.pdf
# hal ID: hal-01578075
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01578075_v1_main_moulinFrieretalTCDS17.pdf
# hal ID: hal-01578648
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01578648_v1_main_1049.pdf
# hal ID: hal-01581794
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01581794_v1_main_arith_hal.pdf
# hal ID: hal-01583301
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01583301_v1_main_paper.pdf
# hal ID: hal-01543919
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01543919_v2_main_hmatdirect.pdf
# hal ID: hal-01587652
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01587652_v1_main_isprs-annals-IV-2-W3-67-2017.pdf
# hal ID: hal-01588407
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01588407_v1_main_v5.pdf
# hal ID: hal-01588749
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01588749_v1_main_Modave2017_ProcAcomen.pdf
# hal ID: hal-01287127
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01287127_v1_main_AA_DFJV_FinalVersion.pdf
# hal ID: hal-01589463
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01589463_v1_main_lre_extended.pdf
# hal ID: hal-01371163
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01371163_v2_main_BoCNRevised.pdf
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01371163_v2_main_Iterations.pdf
# hal ID: hal-01590598
# hal ID: hal-01593225
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01593225_v1_main_euler-hal.pdf
# hal ID: hal-01239676
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01239676_v1_main_2015_Fabre_Evolutionary%20Applications_%7B6F4C29D7-8FBC-4842-A4B6-FBBBB7963D26%7D.pdf
# hal ID: hal-01335153
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01335153_v3_main_BoCC17.pdf
# hal ID: hal-01618379
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01618379_v1_main_1706.07270.pdf
# hal ID: hal-01623281
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01623281_v1_main_Leblond-Ponomarev_corr.pdf
# hal ID: hal-01627758
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01627758_v1_main_Kazolea_ejmflu.pdf
# hal ID: hal-01399337
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01399337_v2_main_template-hal.pdf
# hal ID: hal-01628762
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01628762_v1_main_2017_ECMR_LookAtThisOne.pdf
# hal ID: hal-01629426
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01629426_v1_main_iros2017_final.pdf
# hal ID: hal-01629451
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01629451_v1_main_main_final.pdf
# hal ID: hal-01629727
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01629727_v1_main_maeda17a.pdf
# hal ID: hal-01626376
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01626376_v1_main_SPP_Abdel.pdf
# hal ID: hal-01598238
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01598238_v1_main_final-waves-2017-bem-submission.pdf
# hal ID: hal-01643498
# hal ID: hal-01644010
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01644010_v1_main_paper.pdf
# hal ID: hal-01644014
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01644014_v1_main_paper_compliant.pdf
# hal ID: hal-01644423
# hal ID: hal-01647185
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01647185_v1_main_1703.05178.pdf
# hal ID: hal-01648045
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01648045_v1_main_article_mcrf_multi_rev2.pdf
# hal ID: hal-01753111
# Téléchargé: /data/pdf_de_hal/2025/2025_06_11/hal-01753111_v2_main_PDF_Dispositif_Poppy_Education_didapro2017.pdf
# hal ID: hal-01653037
# hal ID: hal-01653593
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 278
#     276 if is_valid_filename(pdf_filename): # on vérifie que c'est bien un nom de fichier pour éviter les urls qui renvoient sur une page html (ex: elsevier)
#     277     try:
# --> 278         response = requests.get(uri)
#     279         response.raise_for_status()  # Vérifie si la requête a échoué
#     280         with open(pdf_filename, 'wb') as pdf_file:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(f"notices sous embargo : {compte_embargo}")
print(f"nb fichiers non enregistrés car externalLink : {compte_externalLink}")
print(f"nbre notices xml enregistrées : {compteur_notices_enregistrees}")
print(f"nbre de fichiers enregistrés : {compteur_telechargements}")


logging.info("Synchro 2e partie terminée.")
print("Synchro 2e partie terminée.")
# Out:
# notices sous embargo : 0
# nb fichiers non enregistrés car externalLink : 0
# nbre notices xml enregistrées : 470
# nbre de fichiers enregistrés : 345
# Synchro 2e partie terminée.
